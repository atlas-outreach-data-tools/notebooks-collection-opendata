# %%
# Parameters
input_release: 'placeholder'
input_DSID: 'placeholder'
output_file: 'placeholder'
evgen_file: 'placeholder'

# %% [markdown]
# # ATLAS Open Event Generation
#
# ATLAS has released a significant amount of [event generator output](https://opendata.atlas.cern/docs/data/for_research/evgen_data) as open data, in HEPMC2 format. This notebook shows a simple example of how to work with those open data.
#
# ## Initialization
#
# We'll start by installing a couple of key packages using `pip`:
# * [atlasopenmagic](https://opendata.atlas.cern/docs/atlasopenmagic) provides convenient access to metadata and file locations
# * [pyhepmc](https://scikit-hep.org/pyhepmc/) provides convenient ways to play with HEPMC files
# * [graphviz](https://pypi.org/project/graphviz/) provides cool visualization interfaces for the events

# %%
# %pip install atlasopenmagic==1.4.2 pyhepmc graphviz
# Out:
# Requirement already satisfied: atlasopenmagic==1.4.2 in /opt/conda/lib/python3.11/site-packages (1.4.2)
# Requirement already satisfied: pyhepmc in /opt/conda/lib/python3.11/site-packages (2.14.0)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.11/site-packages (0.21)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from atlasopenmagic==1.4.2) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from atlasopenmagic==1.4.2) (2.32.4)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/lib/python3.11/site-packages (from pyhepmc) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from pyhepmc) (24.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->atlasopenmagic==1.4.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->atlasopenmagic==1.4.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->atlasopenmagic==1.4.2) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->atlasopenmagic==1.4.2) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Finding and downloading a file to work with
#
# We'll start from atlasopenmagic and set it up to load the open event generation data.

# %%
import atlasopenmagic as atom
# atom.set_release('2025r-evgen', local_path="eos")
atom.set_release(input_release)
# Out:
# Fetching and caching all metadata for release: 2025r-evgen...
# Successfully cached 5399 datasets.
# Active release: 2025r-evgen. (Datasets path: REMOTE)

# %% [markdown]
# Let's grab a file to play with from one of our open generation datasets. You can pick any dataset from those listed on the [Open Data Portal](https://opendata.cern/record/160000).

# %%
# We'll print all the metadata from the sample (cross section, k-factor, etc)
print(atom.get_metadata(input_DSID))
# Get the URLs for the files in the dataset. We disable caching because we are
# going to download the files ourselves, by hand
my_urls = atom.get_urls(input_DSID, protocol='https', cache=False)
print(f'Will test with file {my_urls[0]}')
# Out:
# {'dataset_number': '301000', 'physics_short': 'PowhegPythia8EvtGen_AZNLOCTEQ6L1_DYee_120M180', 'e_tag': None, 'cross_section_pb': 17.477, 'genFiltEff': 1.0, 'kFactor': 1.0, 'nEvents': 4890000, 'sumOfWeights': None, 'sumOfWeightsSquared': None, 'process': None, 'generator': 'Powheg(v1_r2856)+Pythia8(v8.186)+EvtGen(v1.2.0)+Photospp', 'keywords': ['2electron', 'Specialised', 'drellyan', 'electroweak', 'nlo', 'sm', 'z'], 'description': 'POWHEG+Pythia8 Z->ee production without lepton filter and AZNLO CT10 tune', 'job_path': 'https://gitlab.cern.ch/atlas-physics/pmg/infrastructure/mc15joboptions/-/blob/master/share/DSID301xxx/MC15.301000.PowhegPythia8EvtGen_AZNLOCTEQ6L1_DYee_120M180.py', 'CoMEnergy': 13000.0, 'GenEvents': 6100000, 'GenTune': 'AZNLO CTEQ6L1', 'PDF': 'NULL', 'Release': 'AtlasProduction_19.2.3.5', 'Filters': '', 'release': {'name': '2025r-evgen'}}
# Will test with file https://opendata.cern.ch/eos/opendata/atlas/rucio/mc16_13TeV/HEPMC.43646131._000001.tar.gz.1

# %% [markdown]
# Now let's download that file locally. The files are about 500 MB, which takes about a minute to get to the node most of the time.

# %%
import os
from pathlib import Path
# Pull down the entire file using urllib's request functionality
import urllib.request
# Use tarfile to get the HEPMC file out of the tar.gz file
import tarfile

# Make sure output directory exists
Path(os.path.dirname(evgen_file)).mkdir(parents=True, exist_ok=True)

# Download the tarball
(local_filename, headers) = urllib.request.urlretrieve(my_urls[0])

# Open the tarball
with tarfile.open(local_filename, mode="r:gz") as tar_file:
    # There should be only one member - the HEPMC file
    hepmc_file = tar_file.getmembers()[0]
    
    # Extract to a temporary location
    tar_file.extract(hepmc_file, path=os.path.dirname(evgen_file))
    
    # Move/rename it to match the requested output_file
    extracted_path = os.path.join(os.path.dirname(evgen_file), hepmc_file.name)
    os.replace(extracted_path, evgen_file)

print(f"Extracted {hepmc_file.name} → {evgen_file}")
# Out:
# Extracted HEPMC.43646131._000001.hepmc from the tarfile

# %% [markdown]
# ## Using pyhepmc to inspect the events
#
# First we'll do something very simple: **open the file and print the first event
# in text form**. These text-form events are *very long*, but with some practice
# they can be "easy" to read. A vertex (Vtx) represents a single interaction
# in a tree-like structure, and each vertex has a list of particles that are
# input ("I") and output ("O"). Every vertex, and every particle, has a status
# that says something about how it was produced or what it means. For example,
# particles with `status==1` are "stable" and will enter the detector.

# %%
import pyhepmc
# We'll also import graphviz for visualization
import graphviz
# Open the file itself
my_hepmc = pyhepmc.open(evgen_file)
# Read the first event out of the file
my_first_event = my_hepmc.read()
# Using 'print' prints the event in ASCII format
print(my_first_event)
# Out:
# ________________________________________________________________________
# GenEvent: #1
#  Momentum units: MEV Position units: MM
#  Entries in this event: 516 vertices, 861 particles, 1 weights.
#  Position offset: 0, 0, 0, 0
#                                     GenParticle Legend
#          ID    PDG ID   ( px,       py,       pz,     E )   Stat ProdVtx
# ________________________________________________________________________
# Vtx:     -1 stat:   0 (X,cT): 0
#  I:       1     2212 +0.00e+00,+0.00e+00,+6.50e+06,+6.50e+06   4     0
#  O:       2       21 +6.11e+02,-2.32e+03,+4.39e+05,+4.39e+05  61    -1
#           3       21 +2.78e+02,+1.22e+02,+3.14e+04,+3.14e+04  61    -1
#           4       21 +9.11e+02,+9.15e+02,+1.26e+05,+1.26e+05  61    -1
#           5       21 +1.39e+03,+1.56e+02,+5.41e+05,+5.41e+05  61    -1
#           6        2 +4.36e+00,+1.06e+03,+1.56e+03,+1.89e+03  61    -1
#           7       21 -7.92e+02,+6.16e+02,+3.01e+03,+3.18e+03  61    -1
#           8     2203 -3.28e+02,-4.03e+02,+3.85e+06,+3.85e+06  63    -1
#           9        1 -6.96e+02,-4.29e+01,+1.40e+06,+1.40e+06  63    -1
#          10       -2 -1.38e+03,-1.05e+02,+1.06e+05,+1.06e+05  63    -1
# Vtx:     -2 stat:   0 (X,cT): 0
#  I:      11     2212 +0.00e+00,+0.00e+00,-6.50e+06,+6.50e+06   4     0
#  O:      12       21 -1.13e+03,+5.94e+02,-2.49e+06,+2.49e+06  61    -2
#          13       21 +1.27e+03,-2.11e+03,-1.39e+05,+1.39e+05  61    -2
#          14       21 -1.25e+03,+7.86e+01,-1.47e+03,+1.93e+03  61    -2
#          15       21 +8.96e+00,+3.14e+03,-2.45e+05,+2.45e+05  61    -2
#          16       21 +7.24e+02,-1.92e+02,-7.83e+03,+7.87e+03  61    -2
#          17       21 +1.05e+03,-2.23e+03,-1.33e+05,+1.33e+05  61    -2
#          18     2101 +1.43e+02,+2.13e+02,-2.15e+06,+2.15e+06  63    -2
#          19        2 -8.22e+02,+5.10e+02,-1.33e+06,+1.33e+06  63    -2
# Vtx:     -3 stat:   0 (X,cT): 0
#  I:       2       21 +6.11e+02,-2.32e+03,+4.39e+05,+4.39e+05  61    -1
#  O:      20       21 -1.63e-10,+2.13e-10,+4.39e+05,+4.39e+05  42    -3
# Vtx:     -4 stat:   0 (X,cT): 0
#  I:       3       21 +2.78e+02,+1.22e+02,+3.14e+04,+3.14e+04  61    -1
#  O:      21       21 -2.29e-11,-5.50e-11,+3.14e+04,+3.14e+04  53    -4
# Vtx:     -5 stat:   0 (X,cT): 0
#  I:       4       21 +9.11e+02,+9.15e+02,+1.26e+05,+1.26e+05  61    -1
#  O:      22       21 +2.59e-11,+1.14e-12,+1.26e+05,+1.26e+05  53    -5
# Vtx:     -6 stat:   0 (X,cT): 0
#  I:       5       21 +1.39e+03,+1.56e+02,+5.41e+05,+5.41e+05  61    -1
#  O:      23       21 -1.71e-09,-2.89e-08,+5.41e+05,+5.41e+05  53    -6
# Vtx:     -7 stat:   0 (X,cT): 0
#  I:       6        2 +4.36e+00,+1.06e+03,+1.56e+03,+1.89e+03  61    -1
#  O:      24        2 +0.00e+00,+0.00e+00,+1.72e+03,+1.72e+03  31    -7
# Vtx:     -8 stat:   0 (X,cT): 0
#  I:       7       21 -7.92e+02,+6.16e+02,+3.01e+03,+3.18e+03  61    -1
#  O:      25       21 +0.00e+00,+0.00e+00,+3.10e+03,+3.10e+03  31    -8
# Vtx:     -9 stat:   0 (X,cT): 0
#  I:       8     2203 -3.28e+02,-4.03e+02,+3.85e+06,+3.85e+06  63    -1
#  O:      26     2203 -3.28e+02,-4.03e+02,+3.85e+06,+3.85e+06  71    -9
# Vtx:    -10 stat:   0 (X,cT): 0
#  I:       9        1 -6.96e+02,-4.29e+01,+1.40e+06,+1.40e+06  63    -1
#  O:      27        1 -6.96e+02,-4.29e+01,+1.40e+06,+1.40e+06  71   -10
# Vtx:    -11 stat:   0 (X,cT): 0
#  I:      10       -2 -1.38e+03,-1.05e+02,+1.06e+05,+1.06e+05  63    -1
#  O:      28       -2 -1.38e+03,-1.05e+02,+1.06e+05,+1.06e+05  71   -11
# Vtx:    -12 stat:   0 (X,cT): 0
#  I:      12       21 -1.13e+03,+5.94e+02,-2.49e+06,+2.49e+06  61    -2
#  O:      29       21 +1.35e-10,-2.42e-10,-2.49e+06,+2.49e+06  41   -12
# Vtx:    -13 stat:   0 (X,cT): 0
#  I:      13       21 +1.27e+03,-2.11e+03,-1.39e+05,+1.39e+05  61    -2
#  O:      30       21 +5.51e-10,-3.37e-10,-1.39e+05,+1.39e+05  53   -13
# Vtx:    -14 stat:   0 (X,cT): 0
#  I:      14       21 -1.25e+03,+7.86e+01,-1.47e+03,+1.93e+03  61    -2
#  O:      31       21 +5.55e-12,+7.22e-13,-1.70e+03,+1.70e+03  53   -14
# Vtx:    -15 stat:   0 (X,cT): 0
#  I:      15       21 +8.96e+00,+3.14e+03,-2.45e+05,+2.45e+05  61    -2
#  O:      32       21 +6.38e-10,-2.28e-10,-2.45e+05,+2.45e+05  53   -15
# Vtx:    -16 stat:   0 (X,cT): 0
#  I:      16       21 +7.24e+02,-1.92e+02,-7.83e+03,+7.87e+03  61    -2
#  O:      33       21 +0.00e+00,+0.00e+00,-7.92e+03,+7.92e+03  31   -16
# Vtx:    -17 stat:   0 (X,cT): 0
#  I:      17       21 +1.05e+03,-2.23e+03,-1.33e+05,+1.33e+05  61    -2
#  O:      34       21 +0.00e+00,+0.00e+00,-1.33e+05,+1.33e+05  31   -17
# Vtx:    -18 stat:   0 (X,cT): 0
#  I:      18     2101 +1.43e+02,+2.13e+02,-2.15e+06,+2.15e+06  63    -2
#  O:      35     2101 +1.43e+02,+2.13e+02,-2.15e+06,+2.15e+06  71   -18
# Vtx:    -19 stat:   0 (X,cT): 0
#  I:      19        2 -8.22e+02,+5.10e+02,-1.33e+06,+1.33e+06  63    -2
#  O:      36        2 -8.22e+02,+5.10e+02,-1.33e+06,+1.33e+06  71   -19
# Vtx:    -20 stat:   0 (X,cT): 0
#  I:      20       21 -1.63e-10,+2.13e-10,+4.39e+05,+4.39e+05  42    -3
#  O:      37       21 +1.96e-12,+3.63e-11,+4.39e+05,+4.39e+05  42   -20
# Vtx:    -21 stat:   0 (X,cT): 0
#  I:      21       21 -2.29e-11,-5.50e-11,+3.14e+04,+3.14e+04  53    -4
#  O:      38       21 -2.22e-13,+4.44e-13,+2.96e+04,+2.96e+04  41   -21
# Vtx:    -22 stat:   0 (X,cT): 0
#  I:      22       21 +2.59e-11,+1.14e-12,+1.26e+05,+1.26e+05  53    -5
#  O:      39       21 +1.11e-13,+2.22e-13,+1.20e+05,+1.20e+05  41   -22
# Vtx:    -23 stat:   0 (X,cT): 0
#  I:      23       21 -1.71e-09,-2.89e-08,+5.41e+05,+5.41e+05  53    -6
#  O:      40       21 -4.16e-14,+4.44e-13,+4.40e+05,+4.40e+05  41   -23
# Vtx:    -24 stat:   0 (X,cT): 0
#  I:      24        2 +0.00e+00,+0.00e+00,+1.72e+03,+1.72e+03  31    -7
#          33       21 +0.00e+00,+0.00e+00,-7.92e+03,+7.92e+03  31   -16
#  O:      41        2 +8.47e+02,-2.56e+02,+1.57e+03,+1.83e+03  33   -24
#          42       21 -8.47e+02,+2.56e+02,-7.76e+03,+7.81e+03  33   -24
# Vtx:    -25 stat:   0 (X,cT): 0
#  I:      25       21 +0.00e+00,+0.00e+00,+3.10e+03,+3.10e+03  31    -8
#          34       21 +0.00e+00,+0.00e+00,-1.33e+05,+1.33e+05  31   -17
#  O:      43       21 +6.04e+02,-2.57e+01,+3.07e+03,+3.13e+03  33   -25
#          44       21 -6.04e+02,+2.57e+01,-1.33e+05,+1.33e+05  33   -25
# Vtx:    -26 stat:   0 (X,cT): 0
#  I:      45       21 -3.58e+02,+4.65e+02,-2.48e+06,+2.48e+06  43  -294
#  O:      46       21 -3.58e+02,+4.65e+02,-2.48e+06,+2.48e+06  52   -26
# Vtx:    -27 stat:   0 (X,cT): 0
#  I:      46       21 -3.58e+02,+4.65e+02,-2.48e+06,+2.48e+06  52   -26
#  O:      47       21 -3.58e+02,+4.65e+02,-2.48e+06,+2.48e+06  52   -27
# Vtx:    -28 stat:   0 (X,cT): 0
#  I:      47       21 -3.58e+02,+4.65e+02,-2.48e+06,+2.48e+06  52   -27
#  O:      48       21 -3.57e+02,+4.64e+02,-2.47e+06,+2.47e+06  52   -28
# Vtx:    -29 stat:   0 (X,cT): 0
#  I:      48       21 -3.57e+02,+4.64e+02,-2.47e+06,+2.47e+06  52   -28
#  O:      49       21 +2.20e+02,-2.19e+02,-1.11e+05,+1.11e+05  51   -29
#          50       21 -5.87e+02,+6.94e+02,-2.36e+06,+2.36e+06  51   -29
# Vtx:    -30 stat:   0 (X,cT): 0
#  I:      49       21 +2.20e+02,-2.19e+02,-1.11e+05,+1.11e+05  51   -29
#  O:      51       21 +1.70e+02,-1.93e+02,-1.11e+05,+1.11e+05  62   -30
# Vtx:    -31 stat:   0 (X,cT): 0
#  I:      51       21 +1.70e+02,-1.93e+02,-1.11e+05,+1.11e+05  62   -30
#  O:      52       21 +1.70e+02,-1.93e+02,-1.11e+05,+1.11e+05  71   -31
# Vtx:    -32 stat:   0 (X,cT): 0
#  I:      53       21 -7.27e+02,+3.13e+02,-1.22e+06,+1.22e+06  51  -340
#  O:      54       21 -1.28e+03,+6.03e+02,-1.22e+06,+1.22e+06  62   -32
# Vtx:    -33 stat:   0 (X,cT): 0
#  I:      54       21 -1.28e+03,+6.03e+02,-1.22e+06,+1.22e+06  62   -32
#  O:      55       21 -1.28e+03,+6.03e+02,-1.22e+06,+1.22e+06  71   -33
# Vtx:    -34 stat:   0 (X,cT): 0
#  I:      56       21 +1.37e+02,+3.84e+02,-1.14e+06,+1.14e+06  51  -340
#  O:      57       21 -3.81e+02,+6.57e+02,-1.14e+06,+1.14e+06  62   -34
# Vtx:    -35 stat:   0 (X,cT): 0
#  I:      57       21 -3.81e+02,+6.57e+02,-1.14e+06,+1.14e+06  62   -34
#  O:      58       21 -3.81e+02,+6.57e+02,-1.14e+06,+1.14e+06  71   -35
# Vtx:    -36 stat:   0 (X,cT): 0
#  I:      59       21 -1.96e-12,-3.63e-11,-1.43e+04,+1.43e+04  41  -294
#  O:      60        3 +1.11e-13,+0.00e+00,-1.24e+04,+1.24e+04  42   -36
#          61       -3 +3.46e+01,+6.38e+02,-1.78e+03,+1.96e+03  43   -36
# Vtx:    -37 stat:   0 (X,cT): 0
#  I:      60        3 +1.11e-13,+0.00e+00,-1.24e+04,+1.24e+04  42   -36
#  O:      62        3 +0.00e+00,+0.00e+00,-1.24e+04,+1.24e+04  21   -37
# Vtx:    -38 stat:   0 (X,cT): 0
#  I:      63       21 +0.00e+00,+0.00e+00,+4.39e+05,+4.39e+05  41  -332
#  O:      64       -3 +0.00e+00,+0.00e+00,+3.21e+05,+3.21e+05  21   -38
#          65        3 +1.94e+03,+4.12e+02,+1.18e+05,+1.18e+05  43   -38
# Vtx:    -39 stat:   0 (X,cT): 0
#  I:      64       -3 +0.00e+00,+0.00e+00,+3.21e+05,+3.21e+05  21   -38
#          62        3 +0.00e+00,+0.00e+00,-1.24e+04,+1.24e+04  21   -37
#  O:      66       23 -1.52e+03,+3.69e+03,+2.94e+05,+3.18e+05  22   -39
#          67       21 +1.52e+03,-3.69e+03,+1.45e+04,+1.50e+04  23   -39
# Vtx:    -40 stat:   0 (X,cT): 0
#  I:      67       21 +1.52e+03,-3.69e+03,+1.45e+04,+1.50e+04  23   -39
#  O:      68       21 +1.44e+03,-3.71e+03,+1.45e+04,+1.50e+04  44   -40
# Vtx:    -41 stat:   0 (X,cT): 0
#  I:      68       21 +1.44e+03,-3.71e+03,+1.45e+04,+1.50e+04  44   -40
#  O:      69       21 +1.43e+03,-3.72e+03,+1.46e+04,+1.51e+04  44   -41
# Vtx:    -42 stat:   0 (X,cT): 0
#  I:      69       21 +1.43e+03,-3.72e+03,+1.46e+04,+1.51e+04  44   -41
#  O:      70       21 +1.44e+03,-3.73e+03,+1.47e+04,+1.52e+04  44   -42
# Vtx:    -43 stat:   0 (X,cT): 0
#  I:      70       21 +1.44e+03,-3.73e+03,+1.47e+04,+1.52e+04  44   -42
#  O:      71       21 +8.10e+02,-1.61e+03,+8.70e+03,+8.88e+03  51   -43
#          72       21 +6.31e+02,-2.12e+03,+5.93e+03,+6.33e+03  51   -43
# Vtx:    -44 stat:   0 (X,cT): 0
#  I:      72       21 +6.31e+02,-2.12e+03,+5.93e+03,+6.33e+03  51   -43
#  O:      73       21 +5.08e+01,-2.01e+03,+5.69e+03,+6.03e+03  51   -44
#          74       21 +5.81e+02,-1.11e+02,-6.01e+01,+5.94e+02  51   -44
# Vtx:    -45 stat:   0 (X,cT): 0
#  I:      74       21 +5.81e+02,-1.11e+02,-6.01e+01,+5.94e+02  51   -44
#  O:      75       21 +4.77e+02,-9.11e+01,-4.94e+01,+4.89e+02  52   -45
# Vtx:    -46 stat:   0 (X,cT): 0
#  I:      75       21 +4.77e+02,-9.11e+01,-4.94e+01,+4.89e+02  52   -45
#  O:      76       21 +7.83e+02,-4.57e+02,-7.63e+02,+1.19e+03  51   -46
#          77       21 -3.07e+02,+3.67e+02,-6.60e+03,+6.62e+03  51   -46
# Vtx:    -47 stat:   0 (X,cT): 0
#  I:      77       21 -3.07e+02,+3.67e+02,-6.60e+03,+6.62e+03  51   -46
#  O:      78       21 -2.97e+02,+3.56e+02,-6.39e+03,+6.41e+03  52   -47
# Vtx:    -48 stat:   0 (X,cT): 0
#  I:      78       21 -2.97e+02,+3.56e+02,-6.39e+03,+6.41e+03  52   -47
#  O:      79       21 -2.94e+02,+3.52e+02,-6.33e+03,+6.35e+03  52   -48
# Vtx:    -49 stat:   0 (X,cT): 0
#  I:      79       21 -2.94e+02,+3.52e+02,-6.33e+03,+6.35e+03  52   -48
#  O:      80       21 -2.97e+02,+3.54e+02,-6.33e+03,+6.35e+03  62   -49
# Vtx:    -50 stat:   0 (X,cT): 0
#  I:      80       21 -2.97e+02,+3.54e+02,-6.33e+03,+6.35e+03  62   -49
#  O:      81       21 -2.97e+02,+3.54e+02,-6.33e+03,+6.35e+03  71   -50
# Vtx:    -51 stat:   0 (X,cT): 0
#  I:      82       21 +6.37e+02,-3.71e+02,-6.21e+02,+9.64e+02  52  -346
#  O:      83       21 +6.37e+02,-3.72e+02,-6.22e+02,+9.65e+02  62   -51
# Vtx:    -52 stat:   0 (X,cT): 0
#  I:      83       21 +6.37e+02,-3.72e+02,-6.22e+02,+9.65e+02  62   -51
#  O:      84       21 +6.37e+02,-3.72e+02,-6.22e+02,+9.65e+02  71   -52
# Vtx:    -53 stat:   0 (X,cT): 0
#  I:      85       21 -1.72e+02,-9.30e+02,+1.27e+03,+1.58e+03  51  -345
#  O:      86       21 -6.32e+01,-7.55e+01,+8.02e+02,+8.08e+02  51   -53
#          87       21 +3.79e+01,-9.40e+02,+3.22e+02,+9.94e+02  51   -53
# Vtx:    -54 stat:   0 (X,cT): 0
#  I:      86       21 -6.32e+01,-7.55e+01,+8.02e+02,+8.08e+02  51   -53
#  O:      88       21 -5.80e+01,-4.14e+02,+1.11e+03,+1.18e+03  51   -54
#          89       21 +2.41e+01,-3.88e+02,-5.67e+01,+3.93e+02  51   -54
# Vtx:    -55 stat:   0 (X,cT): 0
#  I:      89       21 +2.41e+01,-3.88e+02,-5.67e+01,+3.93e+02  51   -54
#  O:      90       21 +2.42e+01,-3.89e+02,-5.78e+01,+3.94e+02  62   -55
# Vtx:    -56 stat:   0 (X,cT): 0
#  I:      91       21 +8.58e+00,-2.13e+02,+7.28e+01,+2.25e+02  52  -347
#  O:      92       21 +8.75e+00,-2.13e+02,+7.22e+01,+2.25e+02  62   -56
# Vtx:    -57 stat:   0 (X,cT): 0
#  I:      92       21 +8.75e+00,-2.13e+02,+7.22e+01,+2.25e+02  62   -56
#          90       21 +2.42e+01,-3.89e+02,-5.78e+01,+3.94e+02  62   -55
#  O:      93       21 +3.30e+01,-6.02e+02,+1.43e+01,+6.19e+02  73   -57
# Vtx:    -58 stat:   0 (X,cT): 0
#  I:      93       21 +3.30e+01,-6.02e+02,+1.43e+01,+6.19e+02  73   -57
#  O:      94       21 +3.30e+01,-6.02e+02,+1.43e+01,+6.19e+02  71   -58
# Vtx:    -59 stat:   0 (X,cT): 0
#  I:      95       21 +3.26e+02,-1.10e+03,+4.41e+03,+4.56e+03  51  -345
#  O:      96       21 +3.32e+02,-1.12e+03,+4.41e+03,+4.56e+03  62   -59
# Vtx:    -60 stat:   0 (X,cT): 0
#  I:      96       21 +3.32e+02,-1.12e+03,+4.41e+03,+4.56e+03  62   -59
#          97       21 -5.64e+01,-4.20e+02,+1.11e+03,+1.18e+03  62  -348
#  O:      98       21 +2.75e+02,-1.54e+03,+5.52e+03,+5.75e+03  73   -60
# Vtx:    -61 stat:   0 (X,cT): 0
#  I:      98       21 +2.75e+02,-1.54e+03,+5.52e+03,+5.75e+03  73   -60
#  O:      99       21 +2.75e+02,-1.54e+03,+5.52e+03,+5.75e+03  71   -61
# Vtx:    -62 stat:   0 (X,cT): 0
#  I:     100       21 +8.22e+02,-1.66e+03,+8.69e+03,+8.89e+03  62  -344
#  O:     101       21 +8.22e+02,-1.66e+03,+8.69e+03,+8.89e+03  71   -62
# Vtx:    -63 stat:   0 (X,cT): 0
#  I:     102       21 +0.00e+00,+0.00e+00,-2.37e+05,+2.37e+05  42  -297
#  O:     103       21 -1.67e-13,-4.44e-13,-2.37e+05,+2.37e+05  42   -63
# Vtx:    -64 stat:   0 (X,cT): 0
#  I:     103       21 -1.67e-13,-4.44e-13,-2.37e+05,+2.37e+05  42   -63
#  O:     104       21 -5.33e-11,-1.73e-11,-2.37e+05,+2.37e+05  41   -64
# Vtx:    -65 stat:   0 (X,cT): 0
#  I:     104       21 -5.33e-11,-1.73e-11,-2.37e+05,+2.37e+05  41   -64
#  O:     105       21 +0.00e+00,+0.00e+00,-1.69e+04,+1.69e+04  31   -65
#         106       21 -1.72e+03,-5.32e+02,-2.20e+05,+2.20e+05  43   -65
# Vtx:    -66 stat:   0 (X,cT): 0
#  I:     107       21 +1.11e-13,+2.22e-13,+2.80e+05,+2.80e+05  41  -335
#  O:     108       21 +6.64e-11,+2.05e-11,+1.97e+05,+1.97e+05  42   -66
#         109       21 -5.41e+02,-1.55e+03,+8.35e+04,+8.35e+04  43   -66
# Vtx:    -67 stat:   0 (X,cT): 0
#  I:     108       21 +6.64e-11,+2.05e-11,+1.97e+05,+1.97e+05  42   -66
#  O:     110       21 +0.00e+00,+0.00e+00,+1.97e+05,+1.97e+05  31   -67
# Vtx:    -68 stat:   0 (X,cT): 0
#  I:     110       21 +0.00e+00,+0.00e+00,+1.97e+05,+1.97e+05  31   -67
#         105       21 +0.00e+00,+0.00e+00,-1.69e+04,+1.69e+04  31   -65
#  O:     111       21 +1.08e+03,-1.53e+03,-1.68e+04,+1.69e+04  33   -68
#         112       21 -1.08e+03,+1.53e+03,+1.97e+05,+1.97e+05  33   -68
# Vtx:    -69 stat:   0 (X,cT): 0
#  I:     112       21 -1.08e+03,+1.53e+03,+1.97e+05,+1.97e+05  33   -68
#  O:     113       21 -1.08e+03,+1.53e+03,+1.96e+05,+1.96e+05  44   -69
# Vtx:    -70 stat:   0 (X,cT): 0
#  I:     113       21 -1.08e+03,+1.53e+03,+1.96e+05,+1.96e+05  44   -69
#  O:     114       21 -5.38e+02,+3.09e+03,+1.96e+05,+1.97e+05  44   -70
# Vtx:    -71 stat:   0 (X,cT): 0
#  I:     114       21 -5.38e+02,+3.09e+03,+1.96e+05,+1.97e+05  44   -70
#  O:     115       21 -4.74e+02,+4.16e+03,+1.96e+05,+1.97e+05  44   -71
# Vtx:    -72 stat:   0 (X,cT): 0
#  I:     115       21 -4.74e+02,+4.16e+03,+1.96e+05,+1.97e+05  44   -71
#  O:     116       21 -4.74e+02,+4.16e+03,+1.96e+05,+1.96e+05  52   -72
# Vtx:    -73 stat:   0 (X,cT): 0
#  I:     116       21 -4.74e+02,+4.16e+03,+1.96e+05,+1.96e+05  52   -72
#  O:     117       21 -4.73e+02,+4.15e+03,+1.96e+05,+1.96e+05  52   -73
# Vtx:    -74 stat:   0 (X,cT): 0
#  I:     117       21 -4.73e+02,+4.15e+03,+1.96e+05,+1.96e+05  52   -73
#  O:     118       21 +7.29e+02,+2.37e+03,+1.48e+05,+1.48e+05  51   -74
#         119       21 -1.20e+03,+1.79e+03,+4.81e+04,+4.81e+04  51   -74
# Vtx:    -75 stat:   0 (X,cT): 0
#  I:     118       21 +7.29e+02,+2.37e+03,+1.48e+05,+1.48e+05  51   -74
#  O:     120       21 +4.70e+02,+1.53e+03,+9.54e+04,+9.54e+04  52   -75
# Vtx:    -76 stat:   0 (X,cT): 0
#  I:     120       21 +4.70e+02,+1.53e+03,+9.54e+04,+9.54e+04  52   -75
#  O:     121       21 +1.13e+02,+1.62e+03,+6.62e+04,+6.62e+04  51   -76
#         122       21 +2.43e+02,+1.08e+02,+3.27e+04,+3.27e+04  51   -76
# Vtx:    -77 stat:   0 (X,cT): 0
#  I:     122       21 +2.43e+02,+1.08e+02,+3.27e+04,+3.27e+04  51   -76
#  O:     123       21 +1.85e+02,+8.17e+01,+2.49e+04,+2.49e+04  52   -77
# Vtx:    -78 stat:   0 (X,cT): 0
#  I:     123       21 +1.85e+02,+8.17e+01,+2.49e+04,+2.49e+04  52   -77
#  O:     124       21 +2.48e+02,+8.89e+01,+2.49e+04,+2.49e+04  62   -78
# Vtx:    -79 stat:   0 (X,cT): 0
#  I:     125       21 +1.39e-14,+3.33e-13,+7.56e+04,+7.56e+04  41  -334
#  O:     126       21 -4.22e-12,+1.67e-12,+6.39e+04,+6.39e+04  42   -79
#         127       21 -2.24e+02,+1.63e+03,+4.11e+03,+4.42e+03  43   -79
# Vtx:    -80 stat:   0 (X,cT): 0
#  I:     127       21 -2.24e+02,+1.63e+03,+4.11e+03,+4.42e+03  43   -79
#  O:     128       21 -2.70e+02,+1.74e+03,+4.20e+03,+4.56e+03  44   -80
# Vtx:    -81 stat:   0 (X,cT): 0
#  I:     128       21 -2.70e+02,+1.74e+03,+4.20e+03,+4.56e+03  44   -80
#  O:     129       21 +5.21e+02,+5.49e+02,+6.95e+03,+6.99e+03  51   -81
#         130       21 -1.59e+03,+3.32e+02,+2.81e+03,+3.25e+03  51   -81
# Vtx:    -82 stat:   0 (X,cT): 0
#  I:     129       21 +5.21e+02,+5.49e+02,+6.95e+03,+6.99e+03  51   -81
#  O:     131       21 +1.14e+03,-1.41e+02,+3.07e+04,+3.07e+04  51   -82
#         132       21 -1.04e+02,-5.60e+02,+2.99e+03,+3.04e+03  51   -82
# Vtx:    -83 stat:   0 (X,cT): 0
#  I:     131       21 +1.14e+03,-1.41e+02,+3.07e+04,+3.07e+04  51   -82
#  O:     133       21 +1.05e+03,-1.29e+02,+2.82e+04,+2.82e+04  52   -83
# Vtx:    -84 stat:   0 (X,cT): 0
#  I:     133       21 +1.05e+03,-1.29e+02,+2.82e+04,+2.82e+04  52   -83
#  O:     134       21 +6.78e+02,+1.56e+02,+4.93e+03,+4.98e+03  51   -84
#         135       21 +2.93e+02,-2.31e+02,+2.34e+04,+2.34e+04  51   -84
# Vtx:    -85 stat:   0 (X,cT): 0
#  I:     135       21 +2.93e+02,-2.31e+02,+2.34e+04,+2.34e+04  51   -84
#  O:     136       21 -2.40e+02,-5.07e+02,+1.55e+04,+1.55e+04  51   -85
#         137       21 +4.66e+02,+3.23e+02,+7.93e+03,+7.95e+03  51   -85
# Vtx:    -86 stat:   0 (X,cT): 0
#  I:     137       21 +4.66e+02,+3.23e+02,+7.93e+03,+7.95e+03  51   -85
#  O:     138       21 +3.03e+02,+7.36e+02,+7.14e+03,+7.19e+03  51   -86
#         139       21 +1.56e+00,-3.01e+02,+1.04e+03,+1.09e+03  51   -86
# Vtx:    -87 stat:   0 (X,cT): 0
#  I:     138       21 +3.03e+02,+7.36e+02,+7.14e+03,+7.19e+03  51   -86
#  O:     140       21 +1.84e+02,+4.46e+02,+4.33e+03,+4.36e+03  52   -87
# Vtx:    -88 stat:   0 (X,cT): 0
#  I:     140       21 +1.84e+02,+4.46e+02,+4.33e+03,+4.36e+03  52   -87
#  O:     141       21 -1.38e+02,+2.76e+02,+1.60e+03,+1.63e+03  51   -88
#         142       21 +1.24e+02,+1.80e+01,+1.20e+04,+1.20e+04  51   -88
# Vtx:    -89 stat:   0 (X,cT): 0
#  I:     142       21 +1.24e+02,+1.80e+01,+1.20e+04,+1.20e+04  51   -88
#  O:     143       21 +2.10e+02,+1.05e+02,+1.19e+04,+1.20e+04  62   -89
# Vtx:    -90 stat:   0 (X,cT): 0
#  I:     143       21 +2.10e+02,+1.05e+02,+1.19e+04,+1.20e+04  62   -89
#         124       21 +2.48e+02,+8.89e+01,+2.49e+04,+2.49e+04  62   -78
#  O:     144       21 +4.58e+02,+1.94e+02,+3.68e+04,+3.68e+04  73   -90
# Vtx:    -91 stat:   0 (X,cT): 0
#  I:     144       21 +4.58e+02,+1.94e+02,+3.68e+04,+3.68e+04  73   -90
#  O:     145       21 +4.58e+02,+1.94e+02,+3.68e+04,+3.68e+04  71   -91
# Vtx:    -92 stat:   0 (X,cT): 0
#  I:     146       21 +2.76e+02,-6.96e+02,+4.25e+03,+4.32e+03  51  -352
#  O:     147       21 -6.20e+02,-1.77e+02,+3.55e+03,+3.61e+03  51   -92
#         148       21 +6.38e+02,-7.49e+01,+8.47e+03,+8.49e+03  51   -92
# Vtx:    -93 stat:   0 (X,cT): 0
#  I:     148       21 +6.38e+02,-7.49e+01,+8.47e+03,+8.49e+03  51   -92
#  O:     149       21 +5.29e+02,+1.43e+02,+4.22e+03,+4.25e+03  51   -93
#         150       21 -1.52e+02,+5.85e+01,+1.01e+04,+1.01e+04  51   -93
# Vtx:    -94 stat:   0 (X,cT): 0
#  I:     150       21 -1.52e+02,+5.85e+01,+1.01e+04,+1.01e+04  51   -93
#  O:     151       21 -1.26e+02,+6.14e+01,+1.01e+04,+1.01e+04  62   -94
# Vtx:    -95 stat:   0 (X,cT): 0
#  I:     152       21 -5.14e+02,-1.10e+03,+8.35e+04,+8.35e+04  44  -350
#  O:     153       21 -1.43e+02,-1.04e+03,+1.08e+05,+1.08e+05  51   -95
#         154       21 -1.12e+02,+7.82e+02,+2.82e+04,+2.82e+04  51   -95
# Vtx:    -96 stat:   0 (X,cT): 0
#  I:     154       21 -1.12e+02,+7.82e+02,+2.82e+04,+2.82e+04  51   -95
#  O:     155       21 -3.58e+02,+5.89e+02,+5.59e+04,+5.59e+04  51   -96
#         156       21 +2.05e+02,-1.04e+02,+3.20e+03,+3.21e+03  51   -96
# Vtx:    -97 stat:   0 (X,cT): 0
#  I:     155       21 -3.58e+02,+5.89e+02,+5.59e+04,+5.59e+04  51   -96
#  O:     157       21 -1.32e+02,+2.17e+02,+2.06e+04,+2.06e+04  52   -97
# Vtx:    -98 stat:   0 (X,cT): 0
#  I:     157       21 -1.32e+02,+2.17e+02,+2.06e+04,+2.06e+04  52   -97
#  O:     158       21 -7.91e+01,+2.23e+02,+2.06e+04,+2.06e+04  62   -98
# Vtx:    -99 stat:   0 (X,cT): 0
#  I:     158       21 -7.91e+01,+2.23e+02,+2.06e+04,+2.06e+04  62   -98
#         151       21 -1.26e+02,+6.14e+01,+1.01e+04,+1.01e+04  62   -94
#  O:     159       21 -2.06e+02,+2.84e+02,+3.07e+04,+3.07e+04  73   -99
# Vtx:   -100 stat:   0 (X,cT): 0
#  I:     159       21 -2.06e+02,+2.84e+02,+3.07e+04,+3.07e+04  73   -99
#  O:     160       21 -2.06e+02,+2.84e+02,+3.07e+04,+3.07e+04  71  -100
# Vtx:   -101 stat:   0 (X,cT): 0
#  I:     161       21 +2.82e+02,+1.64e+03,+6.62e+04,+6.62e+04  62  -353
#  O:     162       21 +2.82e+02,+1.64e+03,+6.62e+04,+6.62e+04  71  -101
# Vtx:   -102 stat:   0 (X,cT): 0
#  I:     163       21 -2.45e+02,+4.15e+02,+1.21e+04,+1.21e+04  51  -364
#  O:     164       21 -2.14e+02,+4.19e+02,+1.21e+04,+1.21e+04  62  -102
# Vtx:   -103 stat:   0 (X,cT): 0
#  I:     165       21 -1.45e+03,+2.50e+03,+4.38e+04,+4.39e+04  51  -352
#  O:     166       21 -1.19e+03,+2.06e+03,+3.60e+04,+3.61e+04  52  -103
# Vtx:   -104 stat:   0 (X,cT): 0
#  I:     166       21 -1.19e+03,+2.06e+03,+3.60e+04,+3.61e+04  52  -103
#  O:     167       21 -1.08e+03,+1.86e+03,+3.25e+04,+3.26e+04  52  -104
# Vtx:   -105 stat:   0 (X,cT): 0
#  I:     167       21 -1.08e+03,+1.86e+03,+3.25e+04,+3.26e+04  52  -104
#  O:     168       21 -1.18e+03,+1.25e+03,+2.63e+04,+2.64e+04  51  -105
#         169       21 +1.58e+02,+6.42e+02,+1.40e+04,+1.41e+04  51  -105
# Vtx:   -106 stat:   0 (X,cT): 0
#  I:     169       21 +1.58e+02,+6.42e+02,+1.40e+04,+1.41e+04  51  -105
#  O:     170       21 +1.94e+02,+6.46e+02,+1.40e+04,+1.41e+04  62  -106
# Vtx:   -107 stat:   0 (X,cT): 0
#  I:     170       21 +1.94e+02,+6.46e+02,+1.40e+04,+1.41e+04  62  -106
#         164       21 -2.14e+02,+4.19e+02,+1.21e+04,+1.21e+04  62  -102
#  O:     171       21 -1.92e+01,+1.06e+03,+2.62e+04,+2.62e+04  73  -107
# Vtx:   -108 stat:   0 (X,cT): 0
#  I:     171       21 -1.92e+01,+1.06e+03,+2.62e+04,+2.62e+04  73  -107
#  O:     172       21 -1.92e+01,+1.06e+03,+2.62e+04,+2.62e+04  71  -108
# Vtx:   -109 stat:   0 (X,cT): 0
#  I:     173       21 -9.17e+02,+9.69e+02,+2.05e+04,+2.05e+04  52  -365
#  O:     174       21 -8.64e+02,+9.75e+02,+2.05e+04,+2.05e+04  62  -109
# Vtx:   -110 stat:   0 (X,cT): 0
#  I:     174       21 -8.64e+02,+9.75e+02,+2.05e+04,+2.05e+04  62  -109
#  O:     175       21 -8.64e+02,+9.75e+02,+2.05e+04,+2.05e+04  71  -110
# Vtx:   -111 stat:   0 (X,cT): 0
#  I:     176       21 -1.37e+02,+2.89e+02,+1.66e+03,+1.69e+03  62  -360
#         177       21 -1.88e+02,+5.91e+02,+3.07e+03,+3.13e+03  62  -338
#  O:     178       21 -3.25e+02,+8.80e+02,+4.72e+03,+4.81e+03  73  -111
# Vtx:   -112 stat:   0 (X,cT): 0
#  I:     179       21 -7.79e+02,+1.24e+03,+1.18e+04,+1.19e+04  43  -333
#  O:     180       21 -7.60e+02,+1.21e+03,+1.15e+04,+1.16e+04  52  -112
# Vtx:   -113 stat:   0 (X,cT): 0
#  I:     180       21 -7.60e+02,+1.21e+03,+1.15e+04,+1.16e+04  52  -112
#  O:     181       21 -1.94e+02,+9.78e+02,+5.67e+03,+5.76e+03  51  -113
#         182       21 -6.16e+02,+2.31e+02,+5.87e+03,+5.91e+03  51  -113
# Vtx:   -114 stat:   0 (X,cT): 0
#  I:     181       21 -1.94e+02,+9.78e+02,+5.67e+03,+5.76e+03  51  -113
#  O:     183       21 -1.43e+02,+1.00e+03,+5.66e+03,+5.75e+03  62  -114
# Vtx:   -115 stat:   0 (X,cT): 0
#  I:     183       21 -1.43e+02,+1.00e+03,+5.66e+03,+5.75e+03  62  -114
#         178       21 -3.25e+02,+8.80e+02,+4.72e+03,+4.81e+03  73  -111
#  O:     184       21 -4.68e+02,+1.88e+03,+1.04e+04,+1.06e+04  73  -115
# Vtx:   -116 stat:   0 (X,cT): 0
#  I:     184       21 -4.68e+02,+1.88e+03,+1.04e+04,+1.06e+04  73  -115
#  O:     185       21 -4.68e+02,+1.88e+03,+1.04e+04,+1.06e+04  71  -116
# Vtx:   -117 stat:   0 (X,cT): 0
#  I:     186       21 -5.64e+02,+2.54e+02,+5.87e+03,+5.90e+03  62  -366
#  O:     187       21 -5.64e+02,+2.54e+02,+5.87e+03,+5.90e+03  71  -117
# Vtx:   -118 stat:   0 (X,cT): 0
#  I:     188       21 -5.81e+02,-1.65e+02,+3.33e+03,+3.38e+03  52  -361
#  O:     189       21 -5.34e+02,-1.52e+02,+3.06e+03,+3.11e+03  52  -118
# Vtx:   -119 stat:   0 (X,cT): 0
#  I:     189       21 -5.34e+02,-1.52e+02,+3.06e+03,+3.11e+03  52  -118
#  O:     190       21 -5.26e+02,-1.51e+02,+3.06e+03,+3.11e+03  62  -119
# Vtx:   -120 stat:   0 (X,cT): 0
#  I:     191       21 +3.11e-12,-1.08e-12,-1.69e+03,+1.69e+03  53  -296
#  O:     192       21 +2.22e-13,-4.44e-13,-1.62e+03,+1.62e+03  42  -120
# Vtx:   -121 stat:   0 (X,cT): 0
#  I:     192       21 +2.22e-13,-4.44e-13,-1.62e+03,+1.62e+03  42  -120
#  O:     193       21 +1.39e-14,+0.00e+00,-1.62e+03,+1.62e+03  42  -121
# Vtx:   -122 stat:   0 (X,cT): 0
#  I:     193       21 +1.39e-14,+0.00e+00,-1.62e+03,+1.62e+03  42  -121
#  O:     194       21 +3.55e-12,-1.67e-12,-1.62e+03,+1.62e+03  41  -122
# Vtx:   -123 stat:   0 (X,cT): 0
#  I:     194       21 +3.55e-12,-1.67e-12,-1.62e+03,+1.62e+03  41  -122
#  O:     195       21 -3.33e-13,+1.67e-13,-9.63e+02,+9.63e+02  42  -123
#         196       21 -2.76e+03,+1.17e+03,+3.55e+03,+4.64e+03  43  -123
# Vtx:   -124 stat:   0 (X,cT): 0
#  I:     196       21 -2.76e+03,+1.17e+03,+3.55e+03,+4.64e+03  43  -123
#  O:     197       21 -2.75e+03,+1.06e+03,+4.09e+03,+5.04e+03  44  -124
# Vtx:   -125 stat:   0 (X,cT): 0
#  I:     197       21 -2.75e+03,+1.06e+03,+4.09e+03,+5.04e+03  44  -124
#  O:     198       21 -2.80e+03,+1.18e+03,+4.20e+03,+5.18e+03  44  -125
# Vtx:   -126 stat:   0 (X,cT): 0
#  I:     198       21 -2.80e+03,+1.18e+03,+4.20e+03,+5.18e+03  44  -125
#  O:     199       21 -2.93e+03,+7.44e+02,+5.55e+03,+6.32e+03  51  -126
#         200       21 +6.61e+02,+9.43e+02,+2.15e+03,+2.44e+03  51  -126
# Vtx:   -127 stat:   0 (X,cT): 0
#  I:     199       21 -2.93e+03,+7.44e+02,+5.55e+03,+6.32e+03  51  -126
#  O:     201       21 -2.74e+03,+4.17e+02,+5.00e+03,+5.72e+03  51  -127
#         202       21 +7.21e+01,+6.98e+02,+1.40e+03,+1.57e+03  51  -127
# Vtx:   -128 stat:   0 (X,cT): 0
#  I:     201       21 -2.74e+03,+4.17e+02,+5.00e+03,+5.72e+03  51  -127
#  O:     203       21 -2.39e+03,+4.78e+02,+3.14e+03,+3.98e+03  51  -128
#         204       21 -3.51e+02,-6.07e+01,+1.78e+03,+1.81e+03  51  -128
# Vtx:   -129 stat:   0 (X,cT): 0
#  I:     204       21 -3.51e+02,-6.07e+01,+1.78e+03,+1.81e+03  51  -128
#  O:     205       21 -3.50e+02,-4.61e+01,+1.91e+03,+1.94e+03  62  -129
# Vtx:   -130 stat:   0 (X,cT): 0
#  I:     205       21 -3.50e+02,-4.61e+01,+1.91e+03,+1.94e+03  62  -129
#         190       21 -5.26e+02,-1.51e+02,+3.06e+03,+3.11e+03  62  -119
#  O:     206       21 -8.75e+02,-1.97e+02,+4.97e+03,+5.05e+03  73  -130
# Vtx:   -131 stat:   0 (X,cT): 0
#  I:     207       21 -5.68e+02,-3.23e+02,+3.84e+03,+3.89e+03  51  -355
#  O:     208       21 -5.59e+02,-2.92e+02,+4.04e+03,+4.09e+03  62  -131
# Vtx:   -132 stat:   0 (X,cT): 0
#  I:     208       21 -5.59e+02,-2.92e+02,+4.04e+03,+4.09e+03  62  -131
#         206       21 -8.75e+02,-1.97e+02,+4.97e+03,+5.05e+03  73  -130
#  O:     209       21 -1.43e+03,-4.89e+02,+9.01e+03,+9.14e+03  73  -132
# Vtx:   -133 stat:   0 (X,cT): 0
#  I:     209       21 -1.43e+03,-4.89e+02,+9.01e+03,+9.14e+03  73  -132
#  O:     210       21 -1.43e+03,-4.89e+02,+9.01e+03,+9.14e+03  71  -133
# Vtx:   -134 stat:   0 (X,cT): 0
#  I:     211       21 +0.00e+00,+0.00e+00,+6.39e+04,+6.39e+04  41  -354
#  O:     212       21 +0.00e+00,+0.00e+00,+4.61e+04,+4.61e+04  31  -134
#         213       21 +1.02e+03,-6.54e+02,+1.25e+03,+1.74e+03  43  -134
# Vtx:   -135 stat:   0 (X,cT): 0
#  I:     212       21 +0.00e+00,+0.00e+00,+4.61e+04,+4.61e+04  31  -134
#         214       21 +0.00e+00,+0.00e+00,-9.63e+02,+9.63e+02  31  -367
#  O:     215       21 +4.59e+03,+4.79e+03,+2.05e+04,+2.15e+04  33  -135
#         216       21 -4.59e+03,-4.79e+03,+2.47e+04,+2.56e+04  33  -135
# Vtx:   -136 stat:   0 (X,cT): 0
#  I:     216       21 -4.59e+03,-4.79e+03,+2.47e+04,+2.56e+04  33  -135
#  O:     217       21 -5.15e+03,-4.43e+03,+3.37e+04,+3.44e+04  44  -136
# Vtx:   -137 stat:   0 (X,cT): 0
#  I:     217       21 -5.15e+03,-4.43e+03,+3.37e+04,+3.44e+04  44  -136
#  O:     218       21 -4.18e+03,-4.85e+03,+2.68e+04,+2.76e+04  44  -137
# Vtx:   -138 stat:   0 (X,cT): 0
#  I:     218       21 -4.18e+03,-4.85e+03,+2.68e+04,+2.76e+04  44  -137
#  O:     219       21 -4.08e+03,-5.54e+03,+3.00e+04,+3.07e+04  44  -138
# Vtx:   -139 stat:   0 (X,cT): 0
#  I:     219       21 -4.08e+03,-5.54e+03,+3.00e+04,+3.07e+04  44  -138
#  O:     220       21 -4.41e+03,-4.74e+03,+3.08e+04,+3.15e+04  44  -139
# Vtx:   -140 stat:   0 (X,cT): 0
#  I:     220       21 -4.41e+03,-4.74e+03,+3.08e+04,+3.15e+04  44  -139
#  O:     221       21 -3.61e+03,-3.89e+03,+2.53e+04,+2.58e+04  52  -140
# Vtx:   -141 stat:   0 (X,cT): 0
#  I:     221       21 -3.61e+03,-3.89e+03,+2.53e+04,+2.58e+04  52  -140
#  O:     222       21 -1.17e+03,-1.44e+03,+1.08e+04,+1.09e+04  51  -141
#         223       21 -2.44e+03,-2.45e+03,+1.45e+04,+1.49e+04  51  -141
# Vtx:   -142 stat:   0 (X,cT): 0
#  I:     222       21 -1.17e+03,-1.44e+03,+1.08e+04,+1.09e+04  51  -141
#  O:     224       21 -1.15e+03,-1.36e+03,+1.12e+04,+1.13e+04  62  -142
# Vtx:   -143 stat:   0 (X,cT): 0
#  I:     224       21 -1.15e+03,-1.36e+03,+1.12e+04,+1.13e+04  62  -142
#  O:     225       21 -1.15e+03,-1.36e+03,+1.12e+04,+1.13e+04  71  -143
# Vtx:   -144 stat:   0 (X,cT): 0
#  I:     226       21 -2.48e+03,-2.33e+03,+1.54e+04,+1.57e+04  62  -373
#  O:     227       21 -2.48e+03,-2.33e+03,+1.54e+04,+1.57e+04  71  -144
# Vtx:   -145 stat:   0 (X,cT): 0
#  I:     228       21 -1.02e+02,-5.37e+02,+3.02e+03,+3.07e+03  62  -356
#         229       21 -6.29e+00,-2.92e+02,+1.04e+03,+1.08e+03  62  -359
#  O:     230       21 -1.08e+02,-8.29e+02,+4.06e+03,+4.15e+03  73  -145
# Vtx:   -146 stat:   0 (X,cT): 0
#  I:     230       21 -1.08e+02,-8.29e+02,+4.06e+03,+4.15e+03  73  -145
#  O:     231       21 -1.08e+02,-8.29e+02,+4.06e+03,+4.15e+03  71  -146
# Vtx:   -147 stat:   0 (X,cT): 0
#  I:     232       21 -9.24e+02,+6.44e+02,+1.48e+03,+1.86e+03  51  -355
#  O:     233       21 -8.46e+02,+5.90e+02,+1.36e+03,+1.70e+03  52  -147
# Vtx:   -148 stat:   0 (X,cT): 0
#  I:     233       21 -8.46e+02,+5.90e+02,+1.36e+03,+1.70e+03  52  -147
#  O:     234       21 -7.80e+02,+5.43e+02,+1.25e+03,+1.57e+03  52  -148
# Vtx:   -149 stat:   0 (X,cT): 0
#  I:     234       21 -7.80e+02,+5.43e+02,+1.25e+03,+1.57e+03  52  -148
#  O:     235       21 -6.18e+02,+4.31e+02,+9.91e+02,+1.24e+03  52  -149
# Vtx:   -150 stat:   0 (X,cT): 0
#  I:     235       21 -6.18e+02,+4.31e+02,+9.91e+02,+1.24e+03  52  -149
#  O:     236       21 -7.02e+02,+4.46e+02,+1.24e+03,+1.50e+03  62  -150
# Vtx:   -151 stat:   0 (X,cT): 0
#  I:     237       21 -2.67e+03,+5.29e+02,+4.09e+03,+4.91e+03  62  -370
#         236       21 -7.02e+02,+4.46e+02,+1.24e+03,+1.50e+03  62  -150
#  O:     238       21 -3.37e+03,+9.75e+02,+5.33e+03,+6.41e+03  73  -151
# Vtx:   -152 stat:   0 (X,cT): 0
#  I:     238       21 -3.37e+03,+9.75e+02,+5.33e+03,+6.41e+03  73  -151
#  O:     239       21 -3.37e+03,+9.75e+02,+5.33e+03,+6.41e+03  71  -152
# Vtx:   -153 stat:   0 (X,cT): 0
#  I:     240       21 +1.73e+03,-9.53e+02,+3.30e+03,+3.84e+03  44  -371
#  O:     241       21 +1.74e+03,-1.04e+03,+3.72e+03,+4.24e+03  44  -153
# Vtx:   -154 stat:   0 (X,cT): 0
#  I:     241       21 +1.74e+03,-1.04e+03,+3.72e+03,+4.24e+03  44  -153
#  O:     242       21 +1.70e+03,-9.39e+02,+3.86e+03,+4.32e+03  44  -154
# Vtx:   -155 stat:   0 (X,cT): 0
#  I:     242       21 +1.70e+03,-9.39e+02,+3.86e+03,+4.32e+03  44  -154
#  O:     243       21 +1.61e+03,+5.65e+01,+4.01e+03,+4.32e+03  51  -155
#         244       21 +3.63e+02,-7.32e+02,+1.68e+03,+1.87e+03  51  -155
# Vtx:   -156 stat:   0 (X,cT): 0
#  I:     244       21 +3.63e+02,-7.32e+02,+1.68e+03,+1.87e+03  51  -155
#  O:     245       21 -1.20e+02,+1.15e+02,+7.25e+01,+1.82e+02  51  -156
#         246       21 +8.01e+02,-5.43e+02,+3.72e+03,+3.84e+03  51  -156
# Vtx:   -157 stat:   0 (X,cT): 0
#  I:     245       21 -1.20e+02,+1.15e+02,+7.25e+01,+1.82e+02  51  -156
#  O:     247       21 -1.59e+02,+1.19e+02,+1.27e+02,+2.36e+02  62  -157
# Vtx:   -158 stat:   0 (X,cT): 0
#  I:     248       21 +1.67e-13,-1.11e-13,-1.22e+05,+1.22e+05  42  -295
#  O:     249       21 +2.61e-12,-4.00e-12,-1.22e+05,+1.22e+05  53  -158
# Vtx:   -159 stat:   0 (X,cT): 0
#  I:     249       21 +2.61e-12,-4.00e-12,-1.22e+05,+1.22e+05  53  -158
#  O:     250       21 -2.78e-14,+0.00e+00,-1.21e+05,+1.21e+05  42  -159
# Vtx:   -160 stat:   0 (X,cT): 0
#  I:     250       21 -2.78e-14,+0.00e+00,-1.21e+05,+1.21e+05  42  -159
#  O:     251       21 -3.33e-13,-4.44e-12,-1.21e+05,+1.21e+05  41  -160
# Vtx:   -161 stat:   0 (X,cT): 0
#  I:     251       21 -3.33e-13,-4.44e-12,-1.21e+05,+1.21e+05  41  -160
#  O:     252       21 -1.78e-12,+8.88e-13,-2.68e+04,+2.68e+04  53  -161
#         253       21 +2.70e+02,+2.62e+03,-9.41e+04,+9.42e+04  43  -161
# Vtx:   -162 stat:   0 (X,cT): 0
#  I:     252       21 -1.78e-12,+8.88e-13,-2.68e+04,+2.68e+04  53  -161
#  O:     254       21 +0.00e+00,+0.00e+00,-2.00e+04,+2.00e+04  31  -162
# Vtx:   -163 stat:   0 (X,cT): 0
#  I:     255       21 +0.00e+00,+0.00e+00,+1.78e+04,+1.78e+04  41  -333
#  O:     256        1 +4.72e-13,+4.44e-12,+1.49e+04,+1.49e+04  42  -163
#         257       -1 +4.42e+02,+1.58e+03,+2.58e+03,+3.07e+03  43  -163
# Vtx:   -164 stat:   0 (X,cT): 0
#  I:     256        1 +4.72e-13,+4.44e-12,+1.49e+04,+1.49e+04  42  -163
#  O:     258        1 +0.00e+00,+0.00e+00,+1.49e+04,+1.49e+04  31  -164
# Vtx:   -165 stat:   0 (X,cT): 0
#  I:     258        1 +0.00e+00,+0.00e+00,+1.49e+04,+1.49e+04  31  -164
#         254       21 +0.00e+00,+0.00e+00,-2.00e+04,+2.00e+04  31  -162
#  O:     259        1 +6.30e+03,-6.20e+03,+1.24e+04,+1.53e+04  33  -165
#         260       21 -6.30e+03,+6.20e+03,-1.75e+04,+1.96e+04  33  -165
# Vtx:   -166 stat:   0 (X,cT): 0
#  I:     260       21 -6.30e+03,+6.20e+03,-1.75e+04,+1.96e+04  33  -165
#  O:     261       21 -4.91e+02,+3.14e+02,+1.44e+02,+6.00e+02  51  -166
#         262       21 -5.81e+03,+5.89e+03,-2.45e+04,+2.59e+04  51  -166
# Vtx:   -167 stat:   0 (X,cT): 0
#  I:     261       21 -4.91e+02,+3.14e+02,+1.44e+02,+6.00e+02  51  -166
#  O:     263       21 -4.93e+02,+2.92e+02,+1.29e+02,+5.87e+02  44  -167
# Vtx:   -168 stat:   0 (X,cT): 0
#  I:     263       21 -4.93e+02,+2.92e+02,+1.29e+02,+5.87e+02  44  -167
#  O:     264       21 -5.04e+02,+2.54e+02,+1.37e+02,+5.81e+02  44  -168
# Vtx:   -169 stat:   0 (X,cT): 0
#  I:     264       21 -5.04e+02,+2.54e+02,+1.37e+02,+5.81e+02  44  -168
#  O:     265       21 -4.88e+02,+2.29e+02,+1.57e+02,+5.61e+02  44  -169
# Vtx:   -170 stat:   0 (X,cT): 0
#  I:     265       21 -4.88e+02,+2.29e+02,+1.57e+02,+5.61e+02  44  -169
#  O:     266       21 -1.29e+03,+4.32e+02,-7.12e+02,+1.54e+03  51  -170
#         267       21 +7.31e+01,+2.68e+02,-2.09e+03,+2.11e+03  51  -170
# Vtx:   -171 stat:   0 (X,cT): 0
#  I:     266       21 -1.29e+03,+4.32e+02,-7.12e+02,+1.54e+03  51  -170
#  O:     268       21 -5.40e+02,+4.83e+02,-7.00e+02,+1.01e+03  51  -171
#         269       21 -7.70e+02,-2.08e+01,+2.75e+02,+8.18e+02  51  -171
# Vtx:   -172 stat:   0 (X,cT): 0
#  I:     269       21 -7.70e+02,-2.08e+01,+2.75e+02,+8.18e+02  51  -171
#  O:     270       21 -7.20e+02,-1.94e+01,+2.58e+02,+7.65e+02  52  -172
# Vtx:   -173 stat:   0 (X,cT): 0
#  I:     270       21 -7.20e+02,-1.94e+01,+2.58e+02,+7.65e+02  52  -172
#  O:     271       21 -7.13e+02,-2.13e+01,+2.57e+02,+7.58e+02  62  -173
# Vtx:   -174 stat:   0 (X,cT): 0
#  I:     271       21 -7.13e+02,-2.13e+01,+2.57e+02,+7.58e+02  62  -173
#         247       21 -1.59e+02,+1.19e+02,+1.27e+02,+2.36e+02  62  -157
#  O:     272       21 -8.72e+02,+9.76e+01,+3.84e+02,+9.94e+02  73  -174
# Vtx:   -175 stat:   0 (X,cT): 0
#  I:     272       21 -8.72e+02,+9.76e+01,+3.84e+02,+9.94e+02  73  -174
#  O:     273       21 -8.72e+02,+9.76e+01,+3.84e+02,+9.94e+02  71  -175
# Vtx:   -176 stat:   0 (X,cT): 0
#  I:     274       21 -3.37e+02,+4.98e+02,-1.20e+03,+1.35e+03  51  -380
#  O:     275       21 -3.25e+02,+4.79e+02,-1.21e+03,+1.34e+03  62  -176
# Vtx:   -177 stat:   0 (X,cT): 0
#  I:     276       21 -5.31e+02,+4.71e+02,-7.05e+02,+1.00e+03  62  -381
#         275       21 -3.25e+02,+4.79e+02,-1.21e+03,+1.34e+03  62  -176
#  O:     277       21 -8.56e+02,+9.50e+02,-1.91e+03,+2.34e+03  73  -177
# Vtx:   -178 stat:   0 (X,cT): 0
#  I:     277       21 -8.56e+02,+9.50e+02,-1.91e+03,+2.34e+03  73  -177
#  O:     278       21 -8.56e+02,+9.50e+02,-1.91e+03,+2.34e+03  71  -178
# Vtx:   -179 stat:   0 (X,cT): 0
#  I:     279       21 -7.18e+02,+4.98e+02,-5.46e+03,+5.53e+03  51  -380
#  O:     280       21 -6.68e+02,+4.14e+02,-5.46e+03,+5.52e+03  62  -179
# Vtx:   -180 stat:   0 (X,cT): 0
#  I:     280       21 -6.68e+02,+4.14e+02,-5.46e+03,+5.52e+03  62  -179
#  O:     281       21 -6.68e+02,+4.14e+02,-5.46e+03,+5.52e+03  71  -180
# Vtx:   -181 stat:   0 (X,cT): 0
#  I:     282       21 -1.72e+03,-5.32e+02,-2.20e+05,+2.20e+05  44  -349
#  O:     283       21 -1.72e+03,-5.32e+02,-2.20e+05,+2.20e+05  44  -181
# Vtx:   -182 stat:   0 (X,cT): 0
#  I:     283       21 -1.72e+03,-5.32e+02,-2.20e+05,+2.20e+05  44  -181
#  O:     284       21 -6.82e+02,+5.82e+02,-2.11e+05,+2.11e+05  51  -182
#         285       21 -1.03e+03,-1.11e+03,-8.05e+03,+8.20e+03  51  -182
# Vtx:   -183 stat:   0 (X,cT): 0
#  I:     285       21 -1.03e+03,-1.11e+03,-8.05e+03,+8.20e+03  51  -182
#  O:     286       21 -1.80e+03,-1.80e+03,-5.94e+03,+6.46e+03  51  -183
#         287       21 +7.64e+02,+6.92e+02,-1.79e+03,+2.06e+03  51  -183
# Vtx:   -184 stat:   0 (X,cT): 0
#  I:     286       21 -1.80e+03,-1.80e+03,-5.94e+03,+6.46e+03  51  -183
#  O:     288       21 -1.64e+03,-1.50e+03,-4.51e+03,+5.03e+03  51  -184
#         289       21 -2.03e+02,-2.59e+02,-1.48e+04,+1.48e+04  51  -184
# Vtx:   -185 stat:   0 (X,cT): 0
#  I:     289       21 -2.03e+02,-2.59e+02,-1.48e+04,+1.48e+04  51  -184
#  O:     290       21 -6.28e+02,-4.48e+02,-1.11e+04,+1.12e+04  51  -185
#         291       21 +3.12e+02,+1.08e+02,-3.89e+03,+3.91e+03  51  -185
# Vtx:   -186 stat:   0 (X,cT): 0
#  I:     291       21 +3.12e+02,+1.08e+02,-3.89e+03,+3.91e+03  51  -185
#  O:     292       21 +3.65e+02,-3.39e+02,-2.98e+03,+3.02e+03  51  -186
#         293       21 -3.03e+02,+2.67e+02,-1.45e+03,+1.50e+03  51  -186
# Vtx:   -187 stat:   0 (X,cT): 0
#  I:     293       21 -3.03e+02,+2.67e+02,-1.45e+03,+1.50e+03  51  -186
#  O:     294       21 -3.02e+02,+2.86e+02,-1.45e+03,+1.50e+03  62  -187
# Vtx:   -188 stat:   0 (X,cT): 0
#  I:     295       21 -6.06e+03,+3.43e+03,-2.48e+04,+2.58e+04  44  -379
#  O:     296       21 -6.08e+03,+3.38e+03,-2.47e+04,+2.56e+04  44  -188
# Vtx:   -189 stat:   0 (X,cT): 0
#  I:     296       21 -6.08e+03,+3.38e+03,-2.47e+04,+2.56e+04  44  -188
#  O:     297       21 -5.72e+03,+3.18e+03,-2.32e+04,+2.41e+04  52  -189
# Vtx:   -190 stat:   0 (X,cT): 0
#  I:     297       21 -5.72e+03,+3.18e+03,-2.32e+04,+2.41e+04  52  -189
#  O:     298       21 -5.70e+03,+3.15e+03,-2.30e+04,+2.39e+04  44  -190
# Vtx:   -191 stat:   0 (X,cT): 0
#  I:     298       21 -5.70e+03,+3.15e+03,-2.30e+04,+2.39e+04  44  -190
#  O:     299       21 -5.28e+03,+3.40e+03,-2.14e+04,+2.23e+04  51  -191
#         300       21 -2.91e+02,-8.01e+01,-5.89e+03,+5.90e+03  51  -191
# Vtx:   -192 stat:   0 (X,cT): 0
#  I:     299       21 -5.28e+03,+3.40e+03,-2.14e+04,+2.23e+04  51  -191
#  O:     301       21 -4.55e+03,+2.93e+03,-1.84e+04,+1.92e+04  52  -192
# Vtx:   -193 stat:   0 (X,cT): 0
#  I:     301       21 -4.55e+03,+2.93e+03,-1.84e+04,+1.92e+04  52  -192
#  O:     302       21 -3.36e+03,+2.17e+03,-1.36e+04,+1.42e+04  52  -193
# Vtx:   -194 stat:   0 (X,cT): 0
#  I:     302       21 -3.36e+03,+2.17e+03,-1.36e+04,+1.42e+04  52  -193
#  O:     303       21 -2.23e+03,+1.44e+03,-9.04e+03,+9.43e+03  52  -194
# Vtx:   -195 stat:   0 (X,cT): 0
#  I:     303       21 -2.23e+03,+1.44e+03,-9.04e+03,+9.43e+03  52  -194
#  O:     304       21 -2.15e+03,+1.30e+03,-9.06e+03,+9.40e+03  62  -195
# Vtx:   -196 stat:   0 (X,cT): 0
#  I:     304       21 -2.15e+03,+1.30e+03,-9.06e+03,+9.40e+03  62  -195
#         294       21 -3.02e+02,+2.86e+02,-1.45e+03,+1.50e+03  62  -187
#  O:     305       21 -2.45e+03,+1.59e+03,-1.05e+04,+1.09e+04  73  -196
# Vtx:   -197 stat:   0 (X,cT): 0
#  I:     305       21 -2.45e+03,+1.59e+03,-1.05e+04,+1.09e+04  73  -196
#  O:     306       21 -2.45e+03,+1.59e+03,-1.05e+04,+1.09e+04  71  -197
# Vtx:   -198 stat:   0 (X,cT): 0
#  I:     307       21 -4.19e+02,+4.89e+02,-1.31e+03,+1.46e+03  51  -387
#  O:     308       21 -4.05e+02,+4.68e+02,-1.32e+03,+1.46e+03  62  -198
# Vtx:   -199 stat:   0 (X,cT): 0
#  I:     308       21 -4.05e+02,+4.68e+02,-1.32e+03,+1.46e+03  62  -198
#  O:     309       21 -4.05e+02,+4.68e+02,-1.32e+03,+1.46e+03  71  -199
# Vtx:   -200 stat:   0 (X,cT): 0
#  I:     310       21 -1.54e+03,-1.11e+03,-3.30e+03,+3.81e+03  51  -384
#  O:     311       21 -1.43e+03,-1.03e+03,-3.06e+03,+3.53e+03  52  -200
# Vtx:   -201 stat:   0 (X,cT): 0
#  I:     311       21 -1.43e+03,-1.03e+03,-3.06e+03,+3.53e+03  52  -200
#  O:     312       21 -1.18e+03,-8.50e+02,-2.52e+03,+2.91e+03  52  -201
# Vtx:   -202 stat:   0 (X,cT): 0
#  I:     312       21 -1.18e+03,-8.50e+02,-2.52e+03,+2.91e+03  52  -201
#  O:     313       21 -1.18e+03,-8.16e+02,-2.53e+03,+2.90e+03  62  -202
# Vtx:   -203 stat:   0 (X,cT): 0
#  I:     313       21 -1.18e+03,-8.16e+02,-2.53e+03,+2.90e+03  62  -202
#  O:     314       21 -1.18e+03,-8.16e+02,-2.53e+03,+2.90e+03  71  -203
# Vtx:   -204 stat:   0 (X,cT): 0
#  I:     315       21 +7.59e+02,+6.87e+02,-1.78e+03,+2.05e+03  52  -383
#  O:     316       21 +7.37e+02,+6.67e+02,-1.72e+03,+1.99e+03  52  -204
# Vtx:   -205 stat:   0 (X,cT): 0
#  I:     316       21 +7.37e+02,+6.67e+02,-1.72e+03,+1.99e+03  52  -204
#  O:     317       21 +6.25e+02,-2.16e+02,-1.03e+03,+1.23e+03  51  -205
#         318       21 +7.21e+01,+8.72e+02,-4.63e+02,+9.90e+02  51  -205
# Vtx:   -206 stat:   0 (X,cT): 0
#  I:     318       21 +7.21e+01,+8.72e+02,-4.63e+02,+9.90e+02  51  -205
#  O:     319       21 -2.67e+01,+9.36e+02,+1.15e+02,+9.43e+02  51  -206
#         320       21 +5.17e+01,-7.71e+01,-3.08e+02,+3.21e+02  51  -206
# Vtx:   -207 stat:   0 (X,cT): 0
#  I:     320       21 +5.17e+01,-7.71e+01,-3.08e+02,+3.21e+02  51  -206
#  O:     321       21 +5.17e+01,-7.30e+01,-3.08e+02,+3.21e+02  62  -207
# Vtx:   -208 stat:   0 (X,cT): 0
#  I:     322       21 +9.53e+01,-4.56e+02,-1.53e+03,+1.60e+03  51  -384
#  O:     323       21 +9.54e+01,-4.36e+02,-1.53e+03,+1.60e+03  62  -208
# Vtx:   -209 stat:   0 (X,cT): 0
#  I:     323       21 +9.54e+01,-4.36e+02,-1.53e+03,+1.60e+03  62  -208
#         321       21 +5.17e+01,-7.30e+01,-3.08e+02,+3.21e+02  62  -207
#  O:     324       21 +1.47e+02,-5.09e+02,-1.84e+03,+1.92e+03  73  -209
# Vtx:   -210 stat:   0 (X,cT): 0
#  I:     324       21 +1.47e+02,-5.09e+02,-1.84e+03,+1.92e+03  73  -209
#  O:     325       21 +1.47e+02,-5.09e+02,-1.84e+03,+1.92e+03  71  -210
# Vtx:   -211 stat:   0 (X,cT): 0
#  I:     326       21 -6.79e+02,-2.50e+02,-9.81e+03,+9.83e+03  51  -385
#  O:     327       21 -6.79e+02,-1.24e+02,-9.81e+03,+9.83e+03  62  -211
# Vtx:   -212 stat:   0 (X,cT): 0
#  I:     328       21 -1.06e+03,+1.96e+02,-9.38e+03,+9.44e+03  51  -387
#  O:     329       21 -7.13e+01,-2.55e+02,-9.83e+02,+1.02e+03  51  -212
#         330       21 -7.57e+02,+7.51e+02,-1.57e+04,+1.58e+04  51  -212
# Vtx:   -213 stat:   0 (X,cT): 0
#  I:     329       21 -7.13e+01,-2.55e+02,-9.83e+02,+1.02e+03  51  -212
#  O:     331       21 -5.04e+02,-3.29e+02,-7.33e+03,+7.36e+03  51  -213
#         332       21 -1.63e+02,+6.65e+02,-6.01e+03,+6.04e+03  51  -213
# Vtx:   -214 stat:   0 (X,cT): 0
#  I:     331       21 -5.04e+02,-3.29e+02,-7.33e+03,+7.36e+03  51  -213
#  O:     333       21 -4.36e+02,-4.41e+02,-7.33e+03,+7.36e+03  62  -214
# Vtx:   -215 stat:   0 (X,cT): 0
#  I:     333       21 -4.36e+02,-4.41e+02,-7.33e+03,+7.36e+03  62  -214
#         327       21 -6.79e+02,-1.24e+02,-9.81e+03,+9.83e+03  62  -211
#  O:     334       21 -1.12e+03,-5.65e+02,-1.71e+04,+1.72e+04  73  -215
# Vtx:   -216 stat:   0 (X,cT): 0
#  I:     334       21 -1.12e+03,-5.65e+02,-1.71e+04,+1.72e+04  73  -215
#  O:     335       21 -1.12e+03,-5.65e+02,-1.71e+04,+1.72e+04  71  -216
# Vtx:   -217 stat:   0 (X,cT): 0
#  I:     336       21 +2.79e+03,-1.00e+03,-1.68e+04,+1.70e+04  44  -351
#  O:     337       21 +2.79e+03,-9.99e+02,-1.68e+04,+1.70e+04  44  -217
# Vtx:   -218 stat:   0 (X,cT): 0
#  I:     337       21 +2.79e+03,-9.99e+02,-1.68e+04,+1.70e+04  44  -217
#  O:     338       21 +2.79e+03,-9.99e+02,-1.68e+04,+1.70e+04  44  -218
# Vtx:   -219 stat:   0 (X,cT): 0
#  I:     338       21 +2.79e+03,-9.99e+02,-1.68e+04,+1.70e+04  44  -218
#  O:     339       21 +8.69e+02,-2.40e+02,-2.34e+03,+2.51e+03  51  -219
#         340       21 +1.93e+03,-7.59e+02,-2.29e+04,+2.30e+04  51  -219
# Vtx:   -220 stat:   0 (X,cT): 0
#  I:     339       21 +8.69e+02,-2.40e+02,-2.34e+03,+2.51e+03  51  -219
#  O:     341       21 +1.32e+03,-4.99e+02,-5.19e+03,+5.37e+03  51  -220
#         342       21 +1.94e+01,+7.29e+01,-2.79e+03,+2.79e+03  51  -220
# Vtx:   -221 stat:   0 (X,cT): 0
#  I:     342       21 +1.94e+01,+7.29e+01,-2.79e+03,+2.79e+03  51  -220
#  O:     343       21 +1.96e+01,+1.09e+02,-2.79e+03,+2.79e+03  62  -221
# Vtx:   -222 stat:   0 (X,cT): 0
#  I:     344       21 -1.62e+02,+1.61e+02,-3.36e+03,+3.37e+03  52  -390
#  O:     345       21 -1.31e+02,+1.10e+02,-3.36e+03,+3.37e+03  62  -222
# Vtx:   -223 stat:   0 (X,cT): 0
#  I:     345       21 -1.31e+02,+1.10e+02,-3.36e+03,+3.37e+03  62  -222
#         343       21 +1.96e+01,+1.09e+02,-2.79e+03,+2.79e+03  62  -221
#  O:     346       21 -1.12e+02,+2.18e+02,-6.15e+03,+6.16e+03  73  -223
# Vtx:   -224 stat:   0 (X,cT): 0
#  I:     347       21 -1.07e+02,+5.73e+02,-6.01e+03,+6.04e+03  62  -391
#         346       21 -1.12e+02,+2.18e+02,-6.15e+03,+6.16e+03  73  -223
#  O:     348       21 -2.19e+02,+7.91e+02,-1.22e+04,+1.22e+04  73  -224
# Vtx:   -225 stat:   0 (X,cT): 0
#  I:     348       21 -2.19e+02,+7.91e+02,-1.22e+04,+1.22e+04  73  -224
#  O:     349       21 -2.19e+02,+7.91e+02,-1.22e+04,+1.22e+04  71  -225
# Vtx:   -226 stat:   0 (X,cT): 0
#  I:     350       21 +2.69e+02,+2.61e+03,-9.38e+04,+9.38e+04  44  -376
#  O:     351       21 -1.52e+03,+9.31e+02,-4.93e+04,+4.94e+04  51  -226
#         352       21 +1.44e+03,+1.88e+03,-4.59e+04,+4.60e+04  51  -226
# Vtx:   -227 stat:   0 (X,cT): 0
#  I:     352       21 +1.44e+03,+1.88e+03,-4.59e+04,+4.60e+04  51  -226
#  O:     353       21 +1.44e+03,+1.88e+03,-4.58e+04,+4.59e+04  44  -227
# Vtx:   -228 stat:   0 (X,cT): 0
#  I:     353       21 +1.44e+03,+1.88e+03,-4.58e+04,+4.59e+04  44  -227
#  O:     354       21 +1.30e+03,+1.70e+03,-4.15e+04,+4.16e+04  52  -228
# Vtx:   -229 stat:   0 (X,cT): 0
#  I:     354       21 +1.30e+03,+1.70e+03,-4.15e+04,+4.16e+04  52  -228
#  O:     355       21 +1.07e+03,+1.40e+03,-3.42e+04,+3.43e+04  52  -229
# Vtx:   -230 stat:   0 (X,cT): 0
#  I:     355       21 +1.07e+03,+1.40e+03,-3.42e+04,+3.43e+04  52  -229
#  O:     356       21 +8.55e+02,+1.12e+03,-2.73e+04,+2.73e+04  52  -230
# Vtx:   -231 stat:   0 (X,cT): 0
#  I:     356       21 +8.55e+02,+1.12e+03,-2.73e+04,+2.73e+04  52  -230
#  O:     357       21 +1.11e+03,+7.03e+02,-2.73e+04,+2.73e+04  62  -231
# Vtx:   -232 stat:   0 (X,cT): 0
#  I:     357       21 +1.11e+03,+7.03e+02,-2.73e+04,+2.73e+04  62  -231
#  O:     358       21 +1.11e+03,+7.03e+02,-2.73e+04,+2.73e+04  71  -232
# Vtx:   -233 stat:   0 (X,cT): 0
#  I:     359       21 -1.52e+03,+9.30e+02,-4.92e+04,+4.93e+04  44  -394
#  O:     360       21 -4.68e+02,-2.02e+02,-1.79e+04,+1.79e+04  51  -233
#         361       21 -1.06e+03,+1.13e+03,-4.77e+04,+4.77e+04  51  -233
# Vtx:   -234 stat:   0 (X,cT): 0
#  I:     360       21 -4.68e+02,-2.02e+02,-1.79e+04,+1.79e+04  51  -233
# ...
#  I:     536      111 +7.54e+01,+1.53e+02,+4.15e+02,+4.69e+02   2  -289
#  O:     750       22 +3.51e+01,+1.69e+02,+3.06e+02,+3.52e+02   1  -453
#         751       22 +4.03e+01,-1.60e+01,+1.09e+02,+1.17e+02   1  -453
# Vtx:   -454 stat:   0 (X,cT): 4.7e-05 -5.2e-06 0.00026 0.00027
#  I:     537      111 +1.29e+03,-1.42e+02,+7.28e+03,+7.40e+03   2  -289
#  O:     752       22 +8.42e+02,-2.94e+01,+4.78e+03,+4.85e+03   1  -454
#         753       22 +4.47e+02,-1.13e+02,+2.50e+03,+2.54e+03   1  -454
# Vtx:   -455 stat:   0 (X,cT): 0.00035 8.4e-05 0.002 0.002
#  I:     539      111 +1.10e+03,+2.64e+02,+6.26e+03,+6.37e+03   2  -289
#  O:     754       22 +4.98e+02,+1.59e+02,+2.58e+03,+2.63e+03   1  -455
#         755       22 +6.06e+02,+1.05e+02,+3.69e+03,+3.74e+03   1  -455
# Vtx:   -456 stat:   0 (X,cT): 2.5e-05 -2.4e-05 3.5e-05 5.9e-05
#  I:     541      111 +1.02e+02,-1.00e+02,+1.43e+02,+2.43e+02   2  -289
#  O:     756       22 +1.27e+02,-1.06e+02,+1.41e+02,+2.17e+02   1  -456
#         757       22 -2.53e+01,+5.42e+00,+2.26e+00,+2.60e+01   1  -456
# Vtx:   -457 stat:   0 (X,cT): 0
#  I:     542      213 +1.24e+03,+2.54e+02,+3.23e+03,+3.55e+03   2  -289
#  O:     758      211 +3.09e+02,-2.39e+02,+8.63e+02,+9.58e+02   1  -457
#         759      111 +9.35e+02,+4.93e+02,+2.36e+03,+2.59e+03   2  -457
# Vtx:   -458 stat:   0 (X,cT): 0
#  I:     547      333 +9.05e+02,-2.15e+02,+6.86e+04,+6.86e+04   2  -293
#  O:     760      130 +3.24e+02,-3.65e+01,+2.95e+04,+2.95e+04   1  -458
#         761      310 +5.82e+02,-1.78e+02,+3.91e+04,+3.91e+04   1  -458
# Vtx:   -459 stat:   0 (X,cT): 0
#  I:     562        1 +6.94e+03,-8.16e+03,+1.15e+04,+1.57e+04  51  -305
#  O:     588        1 +7.54e+03,-9.11e+03,+1.11e+04,+1.62e+04  44  -459
# Vtx:   -460 stat:   0 (X,cT): 0
#  I:     566       21 +8.38e+00,-2.04e+03,+1.33e+03,+2.44e+03  51  -307
#  O:     572       21 +5.46e+00,-1.33e+03,+8.66e+02,+1.59e+03  52  -460
# Vtx:   -461 stat:   0 (X,cT): 0
#  I:     574       21 -1.27e+02,+3.14e+01,+1.14e+02,+1.74e+02  51  -312
#  O:     585       21 +5.37e+02,-5.20e+02,+1.44e+02,+7.61e+02  51  -461
#         582       21 +4.02e+02,-8.08e+02,+1.35e+03,+1.62e+03  51  -461
# Vtx:   -462 stat:   0 (X,cT): 0
#  I:     575       21 +2.50e+03,-3.19e+03,+3.23e+03,+5.18e+03  51  -313
#  O:     579       21 +1.43e+03,-1.83e+03,+1.85e+03,+2.97e+03  52  -462
# Vtx:   -463 stat:   0 (X,cT): 0
#  I:     590        1 +1.11e+03,-1.23e+03,+2.50e+03,+3.02e+03  51  -323
#  O:     595        1 +1.14e+03,-1.22e+03,+2.51e+03,+3.04e+03  62  -463
# Vtx:   -464 stat:   0 (X,cT): 0
#  I:     597     2214 +2.78e+03,-3.44e+03,+4.74e+03,+6.60e+03   2  -328
#  O:     762     2212 +1.94e+03,-2.46e+03,+3.06e+03,+4.48e+03   1  -464
#         763      111 +8.48e+02,-9.75e+02,+1.68e+03,+2.12e+03   2  -464
# Vtx:   -465 stat:   0 (X,cT): 0
#  I:     598     -213 +8.46e+02,-2.07e+03,+1.70e+03,+2.91e+03   2  -328
#  O:     764     -211 +2.28e+02,-1.30e+03,+7.26e+02,+1.52e+03   1  -465
#         765      111 +6.18e+02,-7.63e+02,+9.73e+02,+1.39e+03   2  -465
# Vtx:   -466 stat:   0 (X,cT): 0
#  I:     601      313 +1.46e+03,-7.17e+02,+1.10e+03,+2.19e+03   2  -328
#  O:     766      321 +6.20e+02,-3.74e+02,+1.95e+02,+8.98e+02   1  -466
#         767     -211 +8.43e+02,-3.43e+02,+9.06e+02,+1.29e+03   1  -466
# Vtx:   -467 stat:   0 (X,cT): 0
#  I:     605      213 +4.29e+02,-2.82e+02,-8.64e+02,+1.65e+03   2  -328
#  O:     768      211 +7.53e+02,-1.67e+01,-9.27e+02,+1.20e+03   1  -467
#         769      111 -3.25e+02,-2.66e+02,+6.38e+01,+4.45e+02   2  -467
# Vtx:   -468 stat:   0 (X,cT): 0
#  I:     606     -213 +4.24e+02,+2.20e+02,+1.48e+02,+8.66e+02   2  -328
#  O:     770     -211 +4.43e+02,+3.01e+02,+3.14e+02,+6.37e+02   1  -468
#         771      111 -1.95e+01,-8.13e+01,-1.65e+02,+2.29e+02   2  -468
# Vtx:   -469 stat:   0 (X,cT): 0
#  I:     609      113 +1.59e+03,-6.28e+01,-6.84e+03,+7.06e+03   2  -328
#  O:     772      211 +1.45e+03,-1.17e+02,-4.95e+03,+5.17e+03   1  -469
#         773     -211 +1.37e+02,+5.37e+01,-1.89e+03,+1.90e+03   1  -469
# Vtx:   -470 stat:   0 (X,cT): 0
#  I:     610      213 +2.49e+02,-5.56e+02,-9.32e+03,+9.37e+03   2  -328
#  O:     774      211 -2.29e+02,-1.30e+02,-3.70e+03,+3.71e+03   1  -470
#         775      111 +4.78e+02,-4.27e+02,-5.62e+03,+5.66e+03   2  -470
# Vtx:   -471 stat:   0 (X,cT): 0
#  I:     611      113 +1.51e+02,-2.28e+02,-1.24e+04,+1.24e+04   2  -328
#  O:     776      211 -1.63e+01,-1.80e+01,-2.87e+02,+3.20e+02   1  -471
#         777     -211 +1.68e+02,-2.10e+02,-1.21e+04,+1.21e+04   1  -471
# Vtx:   -472 stat:   0 (X,cT): 0.00023 -0.0001 -0.006 0.0061
#  I:     613      111 +2.64e+02,-1.20e+02,-6.92e+03,+6.92e+03   2  -328
#  O:     778       22 +3.55e+01,+1.57e+01,-3.76e+02,+3.78e+02   1  -472
#         779       22 +2.28e+02,-1.35e+02,-6.54e+03,+6.54e+03   1  -472
# Vtx:   -473 stat:   0 (X,cT): -0.00038 -0.00045 -0.052 0.052
#  I:     614      111 -3.58e+02,-4.27e+02,-4.89e+04,+4.89e+04   2  -328
#  O:     780       22 -3.66e+02,-4.30e+02,-4.79e+04,+4.79e+04   1  -473
#         781       22 +7.70e+00,+2.93e+00,-1.04e+03,+1.04e+03   1  -473
# Vtx:   -474 stat:   0 (X,cT): 8.1e-05 4.5e-05 -0.002 0.002
#  I:     615      111 +6.26e+02,+3.48e+02,-1.57e+04,+1.57e+04   2  -328
#  O:     782       22 +2.84e+02,+1.39e+02,-5.55e+03,+5.56e+03   1  -474
#         783       22 +3.42e+02,+2.09e+02,-1.01e+04,+1.01e+04   1  -474
# Vtx:   -475 stat:   0 (X,cT): 0
#  I:     617      221 +1.17e+02,+2.21e+02,-1.86e+06,+1.86e+06   2  -328
#  O:     784       22 +5.97e+01,+4.05e+02,-1.31e+06,+1.31e+06   1  -475
#         785       22 +5.75e+01,-1.84e+02,-5.55e+05,+5.55e+05   1  -475
# Vtx:   -476 stat:   0 (X,cT): -5.9e-05 6.1e-05 -0.072 0.072
#  I:     621      111 -5.75e+02,+6.01e+02,-7.05e+05,+7.05e+05   2  -331
#  O:     786       22 -2.46e+02,+1.73e+02,-2.28e+05,+2.28e+05   1  -476
#         787       22 -3.29e+02,+4.28e+02,-4.77e+05,+4.77e+05   1  -476
# Vtx:   -477 stat:   0 (X,cT): 0
#  I:     624      223 +6.01e+02,+2.18e+02,-1.11e+05,+1.11e+05   2  -331
#  O:     788      211 +8.86e+01,+9.56e+01,-2.94e+04,+2.94e+04   1  -477
#         789     -211 +5.47e+02,+7.06e+01,-7.57e+04,+7.57e+04   1  -477
#         790      111 -3.37e+01,+5.20e+01,-5.96e+03,+5.97e+03   2  -477
#         791       22 +9.27e-04,+1.15e-03,-3.45e-01,+3.45e-01   1  -477
#         792      211 +8.86e+01,+9.56e+01,-2.94e+04,+2.94e+04   3  -477
#         793     -211 +5.47e+02,+7.06e+01,-7.57e+04,+7.57e+04   3  -477
#         794      111 -3.37e+01,+5.20e+01,-5.96e+03,+5.97e+03   3  -477
# Vtx:   -478 stat:   0 (X,cT): 0
#  I:     625      323 -4.67e+01,+6.13e+02,-3.93e+03,+4.08e+03   2  -331
#  O:     795      311 -1.23e+02,+1.11e+02,-1.54e+03,+1.63e+03   2  -478
#         796      211 +7.66e+01,+5.03e+02,-2.39e+03,+2.45e+03   1  -478
# Vtx:   -479 stat:   0 (X,cT): 0
#  I:     626       23 -3.37e+03,+3.30e+03,+2.94e+05,+3.19e+05  44  -343
#  O:     797       23 -3.40e+03,+2.67e+03,+2.94e+05,+3.18e+05  44  -479
# Vtx:   -480 stat:   0 (X,cT): 0
#  I:     635      311 +1.26e+02,+1.27e+03,-3.80e+04,+3.80e+04   2  -401
#  O:     798      130 +1.26e+02,+1.27e+03,-3.80e+04,+3.80e+04   1  -480
# Vtx:   -481 stat:   0 (X,cT): 8.4e-09 2.2e-07 -1.6e-05 1.6e-05
#  I:     636      111 +1.03e+01,+2.75e+02,-1.93e+04,+1.94e+04   2  -401
#  O:     799       22 +6.15e+01,+7.49e+01,-7.52e+03,+7.52e+03   1  -481
#         800       22 -5.12e+01,+2.00e+02,-1.18e+04,+1.18e+04   1  -481
# Vtx:   -482 stat:   0 (X,cT): -1.5e-05 4.7e-05 -0.0053 0.0053
#  I:     639      111 -6.51e+01,+2.06e+02,-2.35e+04,+2.35e+04   2  -402
#  O:     801       22 -3.76e+01,+1.19e+02,-6.88e+03,+6.88e+03   1  -482
#         802       22 -2.75e+01,+8.71e+01,-1.66e+04,+1.66e+04   1  -482
# Vtx:   -483 stat:   0 (X,cT): 8.3e-06 2.3e-05 -0.0044 0.0044
#  I:     641      111 +1.20e+02,+3.25e+02,-6.28e+04,+6.28e+04   2  -403
#  O:     803       22 +1.09e+02,+1.08e+02,-2.38e+04,+2.38e+04   1  -483
#         804       22 +1.07e+01,+2.17e+02,-3.89e+04,+3.89e+04   1  -483
# Vtx:   -484 stat:   0 (X,cT): 9.3e-06 -1.9e-05 -0.0015 0.0015
#  I:     654      111 +6.50e+01,-1.34e+02,-1.02e+04,+1.02e+04   2  -407
#  O:     805       22 +1.19e+01,+1.81e+01,-3.52e+02,+3.53e+02   1  -484
#         806       22 +5.30e+01,-1.52e+02,-9.80e+03,+9.80e+03   1  -484
# Vtx:   -485 stat:   0 (X,cT): 0
#  I:     659      311 +1.63e+02,-1.79e+02,-1.48e+03,+1.58e+03   2  -410
#  O:     807      310 +1.63e+02,-1.79e+02,-1.48e+03,+1.58e+03   1  -485
# Vtx:   -486 stat:   0 (X,cT): 0
#  I:     661     -311 -6.74e+02,-6.68e+02,-7.99e+03,+8.06e+03   2  -411
#  O:     808      310 -6.74e+02,-6.68e+02,-7.99e+03,+8.06e+03   1  -486
# Vtx:   -487 stat:   0 (X,cT): 3.1e-06 -5.9e-06 -8.6e-05 9.5e-05
#  I:     662      111 +1.01e+01,-1.96e+01,-2.85e+02,+3.16e+02   2  -411
#  O:     809       22 +5.93e+01,+4.80e+00,-5.98e+01,+8.43e+01   1  -487
#         810       22 -4.91e+01,-2.44e+01,-2.25e+02,+2.32e+02   1  -487
# Vtx:   -488 stat:   0 (X,cT): -0.00024 -4.2e-05 -0.00052 0.00058
#  I:     664      111 -7.22e+02,-1.25e+02,-1.57e+03,+1.73e+03   2  -412
#  O:     811       22 -1.07e+02,+2.71e+01,-2.68e+02,+2.90e+02   1  -488
#         812       22 -6.15e+02,-1.52e+02,-1.30e+03,+1.44e+03   1  -488
# Vtx:   -489 stat:   0 (X,cT): 0
#  I:     669     -311 -4.05e+02,+4.99e+01,+8.81e+02,+1.09e+03   2  -415
#  O:     813      310 -4.05e+02,+4.99e+01,+8.81e+02,+1.09e+03   1  -489
# Vtx:   -490 stat:   0 (X,cT): 4e-05 5.6e-05 0.00014 0.00016
#  I:     670      111 +1.64e+02,+2.30e+02,+5.85e+02,+6.63e+02   2  -415
#  O:     814       22 +7.42e+01,+6.85e+01,+9.04e+01,+1.36e+02   1  -490
#         815       22 +8.98e+01,+1.61e+02,+4.94e+02,+5.28e+02   1  -490
# Vtx:   -491 stat:   0 (X,cT): 0
#  I:     673     -311 -9.47e+02,-3.00e+02,+6.15e+03,+6.25e+03   2  -417
#  O:     816      130 -9.47e+02,-3.00e+02,+6.15e+03,+6.25e+03   1  -491
# Vtx:   -492 stat:   0 (X,cT): -6.5e-05 -7.7e-05 0.00053 0.00054
#  I:     674      111 -5.84e+02,-6.96e+02,+4.82e+03,+4.90e+03   2  -417
#  O:     817       22 -5.78e+02,-6.99e+02,+4.81e+03,+4.89e+03   1  -492
#         818       22 -6.05e+00,+3.28e+00,+1.14e+01,+1.33e+01   1  -492
# Vtx:   -493 stat:   0 (X,cT): -8.9e-05 0.00015 0.0022 0.0022
#  I:     676      111 -3.58e+02,+6.08e+02,+8.66e+03,+8.69e+03   2  -418
#  O:     819       22 -9.52e+01,+2.21e+02,+3.66e+03,+3.67e+03   1  -493
#         820       22 -2.63e+02,+3.86e+02,+4.99e+03,+5.01e+03   1  -493
# Vtx:   -494 stat:   0 (X,cT): -5.1e-05 0.00013 0.00055 0.00057
#  I:     678      111 -2.82e+02,+7.25e+02,+3.00e+03,+3.11e+03   2  -419
#  O:     821       22 -2.88e+02,+6.55e+02,+2.63e+03,+2.73e+03   1  -494
#         822       22 +5.69e+00,+7.06e+01,+3.71e+02,+3.78e+02   1  -494
# Vtx:   -495 stat:   0 (X,cT): 8.7e-06 2.2e-05 0.00051 0.00051
#  I:     685      111 +6.48e+01,+1.63e+02,+3.82e+03,+3.83e+03   2  -422
#  O:     823       22 +5.00e+01,-2.94e+00,+1.25e+03,+1.25e+03   1  -495
#         824       22 +1.48e+01,+1.66e+02,+2.57e+03,+2.58e+03   1  -495
# Vtx:   -496 stat:   0 (X,cT): 2.1e-05 7.6e-06 0.00034 0.00034
#  I:     688      111 +2.97e+02,+1.08e+02,+4.79e+03,+4.80e+03   2  -423
#  O:     825       22 +1.29e+02,-2.22e+01,+1.87e+03,+1.88e+03   1  -496
#         826       22 +1.68e+02,+1.30e+02,+2.91e+03,+2.92e+03   1  -496
# Vtx:   -497 stat:   0 (X,cT): 0.00058 0.00061 -0.18 0.18
#  I:     700      111 +7.29e+02,+7.65e+02,-2.24e+05,+2.24e+05   2  -429
#  O:     827       22 +1.47e+02,+1.50e+02,-3.41e+04,+3.41e+04   1  -497
#         828       22 +5.83e+02,+6.16e+02,-1.90e+05,+1.90e+05   1  -497
# Vtx:   -498 stat:   0 (X,cT): -1.8e-05 -2.1e-05 -0.0057 0.0057
#  I:     705      111 -2.74e+01,-3.17e+01,-8.51e+03,+8.52e+03   2  -431
#  O:     829       22 -6.21e+00,-4.73e+01,-8.18e+03,+8.18e+03   1  -498
#         830       22 -2.12e+01,+1.56e+01,-3.35e+02,+3.36e+02   1  -498
# Vtx:   -499 stat:   0 (X,cT): 0
#  I:     711     -311 -3.27e+02,+8.74e+01,+3.85e+02,+7.15e+02   2  -435
#  O:     831      310 -3.27e+02,+8.74e+01,+3.85e+02,+7.15e+02   1  -499
# Vtx:   -500 stat:   0 (X,cT): 8.6e-05 -1.1e-05 0.0071 0.0071
#  I:     719      111 +6.18e+02,-8.12e+01,+5.08e+04,+5.08e+04   2  -437
#  O:     832       22 +5.53e+02,-1.14e+02,+4.54e+04,+4.54e+04   1  -500
#         833       22 +6.45e+01,+3.29e+01,+5.37e+03,+5.37e+03   1  -500
# Vtx:   -501 stat:   0 (X,cT): 0
#  I:     731      311 +4.45e+02,-5.30e+02,+4.14e+04,+4.14e+04   2  -445
#  O:     834      130 +4.45e+02,-5.30e+02,+4.14e+04,+4.14e+04   1  -501
# Vtx:   -502 stat:   0 (X,cT): -1.2e-05 -7.4e-06 0.00057 0.00057
#  I:     738      111 -2.58e+02,-1.65e+02,+1.27e+04,+1.27e+04   2  -447
#  O:     835       22 -5.00e+01,-9.76e+01,+5.48e+03,+5.48e+03   1  -502
#         836       22 -2.08e+02,-6.73e+01,+7.23e+03,+7.23e+03   1  -502
# Vtx:   -503 stat:   0 (X,cT): -1.2e-06 -9.6e-05 0.00025 0.00028
#  I:     740      111 -3.09e+00,-2.49e+02,+6.58e+02,+7.17e+02   2  -448
#  O:     837       22 -6.53e+01,-1.73e+02,+4.27e+02,+4.65e+02   1  -503
#         838       22 +6.22e+01,-7.56e+01,+2.32e+02,+2.51e+02   1  -503
# Vtx:   -504 stat:   0 (X,cT): 1.7e-06 4.1e-06 1e-05 1.1e-05
#  I:     743      111 +2.40e+02,+5.77e+02,+1.46e+03,+1.59e+03   2  -449
#  O:     839       22 +3.59e+01,+2.59e+01,+5.33e+01,+6.93e+01   1  -504
#         840       22 +2.04e+02,+5.51e+02,+1.41e+03,+1.53e+03   1  -504
# Vtx:   -505 stat:   0 (X,cT): 5.9e-05 0.00053 0.0018 0.0019
#  I:     749      111 +1.25e+02,+1.14e+03,+3.80e+03,+3.97e+03   2  -452
#  O:     841       22 +1.38e+02,+9.83e+02,+3.16e+03,+3.31e+03   1  -505
#         842       22 -1.31e+01,+1.55e+02,+6.47e+02,+6.65e+02   1  -505
# Vtx:   -506 stat:   0 (X,cT): 2.1e-05 1.1e-05 5.3e-05 5.8e-05
#  I:     759      111 +9.35e+02,+4.93e+02,+2.36e+03,+2.59e+03   2  -457
#  O:     843       22 +8.45e+02,+4.07e+02,+2.15e+03,+2.35e+03   1  -506
#         844       22 +9.06e+01,+8.53e+01,+2.15e+02,+2.49e+02   1  -506
# Vtx:   -507 stat:   0 (X,cT): 0.00026 -0.0003 0.00052 0.00066
#  I:     763      111 +8.48e+02,-9.75e+02,+1.68e+03,+2.12e+03   2  -464
#  O:     845       22 +1.51e+02,-1.29e+02,+3.25e+02,+3.81e+02   1  -507
#         846       22 +6.97e+02,-8.46e+02,+1.35e+03,+1.74e+03   1  -507
# Vtx:   -508 stat:   0 (X,cT): 1.8e-05 -2.2e-05 2.8e-05 4e-05
#  I:     765      111 +6.18e+02,-7.63e+02,+9.73e+02,+1.39e+03   2  -465
#  O:     847       22 +3.85e+02,-5.48e+02,+5.98e+02,+8.97e+02   1  -508
#         848       22 +2.34e+02,-2.15e+02,+3.75e+02,+4.92e+02   1  -508
# Vtx:   -509 stat:   0 (X,cT): -0.00028 -0.00023 5.6e-05 0.00039
#  I:     769      111 -3.25e+02,-2.66e+02,+6.38e+01,+4.45e+02   2  -467
#  O:     849       22 -1.33e+02,-1.94e+02,+4.90e+01,+2.40e+02   1  -509
#         850       22 -1.92e+02,-7.22e+01,+1.49e+01,+2.06e+02   1  -509
# Vtx:   -510 stat:   0 (X,cT): -8e-07 -3.3e-06 -6.8e-06 9.4e-06
#  I:     771      111 -1.95e+01,-8.13e+01,-1.65e+02,+2.29e+02   2  -468
#  O:     851       22 -8.79e+00,+3.10e+01,-4.24e+00,+3.25e+01   1  -510
#         852       22 -1.08e+01,-1.12e+02,-1.61e+02,+1.97e+02   1  -510
# Vtx:   -511 stat:   0 (X,cT): 8.9e-06 -7.9e-06 -0.0001 0.00011
#  I:     775      111 +4.78e+02,-4.27e+02,-5.62e+03,+5.66e+03   2  -470
#  O:     853       22 +4.66e+02,-3.90e+02,-5.00e+03,+5.03e+03   1  -511
#         854       22 +1.18e+01,-3.68e+01,-6.24e+02,+6.25e+02   1  -511
# Vtx:   -512 stat:   0 (X,cT): -2.3e-06 3.6e-06 -0.00041 0.00041
#  I:     790      111 -3.37e+01,+5.20e+01,-5.96e+03,+5.97e+03   2  -477
#  O:     855       22 +4.46e+01,+5.43e+01,-2.79e+03,+2.79e+03   1  -512
#         856       22 -7.83e+01,-2.26e+00,-3.17e+03,+3.17e+03   1  -512
# Vtx:   -513 stat:   0 (X,cT): 0
#  I:     795      311 -1.23e+02,+1.11e+02,-1.54e+03,+1.63e+03   2  -478
#  O:     857      310 -1.23e+02,+1.11e+02,-1.54e+03,+1.63e+03   1  -513
# Vtx:   -514 stat:   0 (X,cT): 0
#  I:     797       23 -3.40e+03,+2.67e+03,+2.94e+05,+3.18e+05  44  -479
#  O:     858       23 -3.10e+03,+2.28e+03,+2.94e+05,+3.18e+05  44  -514
# Vtx:   -515 stat:   0 (X,cT): 0
#  I:     858       23 -3.10e+03,+2.28e+03,+2.94e+05,+3.18e+05  44  -514
#  O:     859       23 -2.68e+03,+6.61e+02,+2.94e+05,+3.18e+05  62  -515
# Vtx:   -516 stat:   0 (X,cT): 0
#  I:     859       23 -2.68e+03,+6.61e+02,+2.94e+05,+3.18e+05  62  -515
#  O:     860       11 -8.96e+02,+4.54e+04,+4.05e+04,+6.09e+04   1  -516
#         861      -11 -1.78e+03,-4.48e+04,+2.54e+05,+2.57e+05   1  -516
# ________________________________________________________________________

# %% [markdown]
# ## Visualize events with pyhepmc and graphviz
#
# All you have to do is have jupyter try to display the event, and with graphviz it
# will display a graph. Note that colab requires some effort to get the graph to
# display properly with graphviz.
#
# This is a huge graph! Feel free to play with the visualization following some of the
# [pyhepmc visualization tutorial](https://scikit-hep.org/pyhepmc/examples/basics.html).

# %%
# Use graphviz to visualize the graph
my_first_event
# Out:
# <GenEvent momentum_unit=0, length_unit=0, event_number=1, particles=861, vertices=516, run_info=GenRunInfo(tools=[], weight_names=['0'], attributes={})>

# %% [markdown]
# ## Examining the particles in the event
#
# Let's look at just the first 15 particles.
#
# We'll be able to see the incoming protons, as well as various particles involved in
# the collision. Notice that the two incoming protons in the collision are *not*
# necessarily the first and second particles in the event! Any analysis of these
# events always takes a bit of care, because the event records might not look the way
# you would naively expect. It's always good to check your assumptions carefully.

# %%
# Print the first 15 particles
my_first_event.particles[:15]
# Out:
# [GenParticle(FourVector(0, 0, 6.5e+06, 6.5e+06), mass=938.27, pid=2212, status=4),
#  GenParticle(FourVector(611, -2.32e+03, 4.39e+05, 4.39e+05), mass=0, pid=21, status=61),
#  GenParticle(FourVector(278, 122, 3.14e+04, 3.14e+04), mass=0, pid=21, status=61),
#  GenParticle(FourVector(911, 915, 1.26e+05, 1.26e+05), mass=0, pid=21, status=61),
#  GenParticle(FourVector(1.39e+03, 156, 5.41e+05, 5.41e+05), mass=0, pid=21, status=61),
#  GenParticle(FourVector(4.36, 1.06e+03, 1.56e+03, 1.89e+03), mass=0, pid=2, status=61),
#  GenParticle(FourVector(-792, 616, 3.01e+03, 3.18e+03), mass=0, pid=21, status=61),
#  GenParticle(FourVector(-328, -403, 3.85e+06, 3.85e+06), mass=771.33, pid=2203, status=63),
#  GenParticle(FourVector(-696, -42.9, 1.4e+06, 1.4e+06), mass=330, pid=1, status=63),
#  GenParticle(FourVector(-1.38e+03, -105, 1.06e+05, 1.06e+05), mass=330, pid=-2, status=63),
#  GenParticle(FourVector(0, 0, -6.5e+06, 6.5e+06), mass=938.27, pid=2212, status=4),
#  GenParticle(FourVector(-1.13e+03, 594, -2.49e+06, 2.49e+06), mass=0, pid=21, status=61),
#  GenParticle(FourVector(1.27e+03, -2.11e+03, -1.39e+05, 1.39e+05), mass=0, pid=21, status=61),
#  GenParticle(FourVector(-1.25e+03, 78.6, -1.47e+03, 1.93e+03), mass=0, pid=21, status=61),
#  GenParticle(FourVector(8.96, 3.14e+03, -2.45e+05, 2.45e+05), mass=0, pid=21, status=61)]

# %% [markdown]
# ## Building histograms from the HEPMC record
#
# Now we'll make a couple of simple histograms by looping over all the events in the file and calculating a few event properties. We'll use the `hist` library, which is a convenient python library for histogramming.
#
# These are di-electron Drell-Yan events, which means we should expect them to almost always have a high-momentum electron and a high-momentum positron. We will look at the mass and momentum of that pair of particles in this example. You can read from the dataset name that we expect the mass to be between 120 and 180 GeV. Notice that we pick out the `status==1` particles, which are the ones that are stable. The status code allows a physicist to pick particles at different stages of the calculation that was used to produce the event.
#
# Here we'll also do a quick conversion, because the particle energies in the file are stored in `MeV`, and we'll draw them in `GeV`.

# %%
# %pip install hist
import hist # Useful library for histogramming
# We will make histograms of the mass and pT of the Drell-Yan events
m_hist = hist.Hist(hist.axis.Regular(40, 120, 180, label="DY mass [GeV]"))
pt_hist = hist.Hist(hist.axis.Regular(40, 0, 200, label="DY p_{T} [GeV]"))
# Open the HEPMC file
with pyhepmc.open(evgen_file) as my_hepmc_input:
    # And loop through all the events
    for event in my_hepmc_input:
        # Because these are Drell-Yan di-electron events, we'll look for the highest transverse-momentum electrons
        electrons = [p for p in sorted(event.particles, key=lambda p:p.momentum.pt()) if abs(p.pid) == 11 and p.status==1]
        # In case we didn't find two electrons that are stable, just keep going
        if len(electrons)<2:
            continue
        # Fill in the histograms with the mass and momentum (with the right units!)
        m_hist.fill((electrons[0].momentum+electrons[1].momentum).m()/1000.)
        pt_hist.fill((electrons[0].momentum+electrons[1].momentum).pt()/1000.)
# Out:
# Collecting hist
#   Downloading hist-2.9.0-py3-none-any.whl.metadata (15 kB)
# Collecting boost-histogram<1.7,>=1.5 (from hist)
#   Downloading boost_histogram-1.6.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (26 kB)
# Collecting histoprint>=2.2.0 (from hist)
#   Downloading histoprint-2.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.19.3 in /opt/conda/lib/python3.11/site-packages (from hist) (1.26.4)
# Requirement already satisfied: click>=7.0.0 in /opt/conda/lib/python3.11/site-packages (from histoprint>=2.2.0->hist) (8.1.7)
# Collecting uhi>=0.2.1 (from histoprint>=2.2.0->hist)
#   Downloading uhi-1.0.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading hist-2.9.0-py3-none-any.whl (42 kB)
# Downloading boost_histogram-1.6.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.2 MB/s  0:00:00
# Downloading histoprint-2.6.0-py3-none-any.whl (16 kB)
# Downloading uhi-1.0.0-py3-none-any.whl (25 kB)
# Installing collected packages: uhi, boost-histogram, histoprint, hist
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [hist]
# Successfully installed boost-histogram-1.6.1 hist-2.9.0 histoprint-2.6.0 uhi-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now we can draw the histograms using matplotlib and numpy, two commonly-used python libraries for histogram making and manipulating arrays of numbers.

# %%
import matplotlib.pyplot as plt
import numpy as np
# Create a canvas that we'll draw the plot on
fig, ax = plt.subplots(figsize=(8, 5))
# Convert the hist histogram into numpy arrays
y, bin_edges = m_hist.to_numpy()
# Calculate a statistical uncertainty on the points
yerr = np.sqrt(y)
# Slightly awkward - convert from bin edges, which is what hist gives us, into bin centers, which is what matplotlib wants
x = [ (bin_edges[n]+bin_edges[n+1])/2. for n in range(len(bin_edges)-1) ]
# Now we can create the actual plot of our data
ax.errorbar(x=x, y=y, yerr=yerr,
                    fmt='ko', # 'k' means black and 'o' is for circles
                    label='Data')
# Set some labels to make it more clear what the plot shows
ax.set_xlabel("Di-electron mass [GeV]")
ax.set_ylabel("Events")
# And finally, do the drawing
plt.savefig(output_file, dpi=300, bbox_inches='tight')
plt.show()

# %%
# And we can draw the transverse momentum plot as well
# This follows the same structure as in the previous cell
fig, ax = plt.subplots(figsize=(8, 5))
y, bin_edges = pt_hist.to_numpy()
yerr = np.sqrt(y)
x = [ (bin_edges[n]+bin_edges[n+1])/2. for n in range(len(bin_edges)-1) ]
ax.errorbar(x=x, y=y, yerr=yerr,
                    fmt='ko', # 'k' means black and 'o' is for circles
                    label='Data')
ax.set_xlabel("Di-electron p_{T} [GeV]")
ax.set_ylabel("Events")
# We'll use a log y-axis so that the full graph is more visible
ax.set_yscale('log')
plt.show()

# %% [markdown]
# Feel free to play yourself and develop your own (more complex) usage for our HEPMC files! If you want to use pyhepmc, there are plenty of [examples available](https://scikit-hep.org/pyhepmc/examples.html).
